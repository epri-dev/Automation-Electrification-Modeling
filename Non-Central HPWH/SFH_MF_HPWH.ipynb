# %% [markdown]
# Welcome to this example script of building electrification WH automation modeling. We will explain step by step what this script does using an example with two input files, one is the target file to be electrified, and the other one is the source file of electrified WH reference.

# %% [markdown]
# First step, install EPPY.

# %%
pip install eppy
# Out:
# Requirement already satisfied: eppy in c:\users\pmsh010\anaconda3\lib\site-packages (0.5.63)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (5.1.1)
# Requirement already satisfied: munch>=2.0.2 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (4.0.0)
# Requirement already satisfied: tinynumpy>=1.2.1 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (1.2.1)
# Requirement already satisfied: beautifulsoup4<=4.8.0 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (4.8.0)
# Requirement already satisfied: lxml>=3.8.0 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (4.8.0)
# Requirement already satisfied: pydot3k in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (1.0.17)
# Requirement already satisfied: future in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (0.18.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (1.16.0)
# Requirement already satisfied: pyparsing>=2.4.7 in c:\users\pmsh010\anaconda3\lib\site-packages (from eppy) (3.0.4)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\pmsh010\anaconda3\lib\site-packages (from beautifulsoup4<=4.8.0->eppy) (2.3.1)
# Requirement already satisfied: setuptools in c:\users\pmsh010\anaconda3\lib\site-packages (from pydot3k->eppy) (61.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Install all packages that might be used

# %%
from eppy import modeleditor
from eppy.modeleditor import IDF
import pandas as pd
import os.path
import glob

# %% [markdown]
# Locate IDD file. In this case I saved IDD under the same folder with this notebook.

# %%
iddfile = 'Energy+.idd'
IDF.setiddname(iddfile)

# %% [markdown]
# Import two idf files. The target idf is the model to be electrified. The source idf is the model with the electrified WH system, regardless whether it's the same building type as the target.

# %% [markdown]
# IMPORTANT: Although the building types and the number of the plants of the target and source files do not have to be the same, the water heating distribution system needs to be aligned - so far, central WH system can only be replaced by another central WH system, and non-central system can only be replaced by another non-central system. A source file with a central WH system CANNOT be used to electrify a target file with a non-central WH system. It has to be one-on-one replacement.

# %%
#target file is DOE reference building of SFH
targetfname = 'US+MF+CZ2AWH+gasfurnace+slab+IECC_2006.idf'
targetidf = IDF(targetfname)

# %%
#source file is a SFH with HPWH
sourcefname = 'US+SF+CZ1AWHT+elecres+slab+IECC_2006_HPWH.idf'
sourceidf = IDF(sourcefname)

# %% [markdown]
# # Find target zones

# %% [markdown]
# We first identify zone served with DHW in the target model. This involve one manual step to rule out the unserved zone(s). The DHW serving zones will be used in the later step of WH electrification replacement.

# %%
#Number of zones in the target model
print(len(targetidf.idfobjects['Zone']))
# Out:
# 20

# %%
#Name of zones, both conditioned and unconditioned, in the target model
zones=[]
for i in range(len(targetidf.idfobjects['Zone'])):
    zones.append(targetidf.idfobjects['Zone'][i].Name)

zones
# Out:
# ['Breezeway',
#  'living_unit1_FrontRow_BottomFloor',
#  'living_unit2_FrontRow_BottomFloor',
#  'living_unit3_FrontRow_BottomFloor',
#  'living_unit1_BackRow_BottomFloor',
#  'living_unit2_BackRow_BottomFloor',
#  'living_unit3_BackRow_BottomFloor',
#  'living_unit1_FrontRow_MiddleFloor',
#  'living_unit2_FrontRow_MiddleFloor',
#  'living_unit3_FrontRow_MiddleFloor',
#  'living_unit1_BackRow_MiddleFloor',
#  'living_unit2_BackRow_MiddleFloor',
#  'living_unit3_BackRow_MiddleFloor',
#  'attic',
#  'living_unit1_FrontRow_TopFloor',
#  'living_unit2_FrontRow_TopFloor',
#  'living_unit3_FrontRow_TopFloor',
#  'living_unit1_BackRow_TopFloor',
#  'living_unit2_BackRow_TopFloor',
#  'living_unit3_BackRow_TopFloor']

# %%
#Rule out unconditioned zone(s) - this step needs manual observation.
zones.remove('attic')
zones.remove('Breezeway')
zones
# Out:
# ['living_unit1_FrontRow_BottomFloor',
#  'living_unit2_FrontRow_BottomFloor',
#  'living_unit3_FrontRow_BottomFloor',
#  'living_unit1_BackRow_BottomFloor',
#  'living_unit2_BackRow_BottomFloor',
#  'living_unit3_BackRow_BottomFloor',
#  'living_unit1_FrontRow_MiddleFloor',
#  'living_unit2_FrontRow_MiddleFloor',
#  'living_unit3_FrontRow_MiddleFloor',
#  'living_unit1_BackRow_MiddleFloor',
#  'living_unit2_BackRow_MiddleFloor',
#  'living_unit3_BackRow_MiddleFloor',
#  'living_unit1_FrontRow_TopFloor',
#  'living_unit2_FrontRow_TopFloor',
#  'living_unit3_FrontRow_TopFloor',
#  'living_unit1_BackRow_TopFloor',
#  'living_unit2_BackRow_TopFloor',
#  'living_unit3_BackRow_TopFloor']

# %%
#review target file object types
target_obj=[]
for obj_type in targetidf.idfobjects:
    for obj in targetidf.idfobjects[obj_type]:
        target_obj.append(obj_type)

unique_target_list=[]        
[unique_target_list.append(x) for x in target_obj if x not in unique_target_list]
unique_target_list
# Out:
# ['VERSION',
#  'SIMULATIONCONTROL',
#  'BUILDING',
#  'SURFACECONVECTIONALGORITHM:INSIDE',
#  'TIMESTEP',
#  'SITE:LOCATION',
#  'SIZINGPERIOD:DESIGNDAY',
#  'RUNPERIOD',
#  'SITE:WATERMAINSTEMPERATURE',
#  'SCHEDULETYPELIMITS',
#  'SCHEDULE:DAY:HOURLY',
#  'SCHEDULE:WEEK:COMPACT',
#  'SCHEDULE:YEAR',
#  'SCHEDULE:COMPACT',
#  'SCHEDULE:CONSTANT',
#  'MATERIAL',
#  'MATERIAL:NOMASS',
#  'MATERIAL:AIRGAP',
#  'WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM',
#  'WINDOWMATERIAL:GLAZING',
#  'WINDOWMATERIAL:BLIND',
#  'CONSTRUCTION',
#  'GLOBALGEOMETRYRULES',
#  'ZONE',
#  'BUILDINGSURFACE:DETAILED',
#  'WINDOW',
#  'DOOR',
#  'WINDOWSHADINGCONTROL',
#  'SHADING:OVERHANG',
#  'GROUNDHEATTRANSFER:CONTROL',
#  'GROUNDHEATTRANSFER:SLAB:MATERIALS',
#  'GROUNDHEATTRANSFER:SLAB:MATLPROPS',
#  'GROUNDHEATTRANSFER:SLAB:BOUNDCONDS',
#  'GROUNDHEATTRANSFER:SLAB:BLDGPROPS',
#  'GROUNDHEATTRANSFER:SLAB:INSULATION',
#  'GROUNDHEATTRANSFER:SLAB:EQUIVALENTSLAB',
#  'GROUNDHEATTRANSFER:BASEMENT:SIMPARAMETERS',
#  'GROUNDHEATTRANSFER:BASEMENT:MATLPROPS',
#  'GROUNDHEATTRANSFER:BASEMENT:INSULATION',
#  'GROUNDHEATTRANSFER:BASEMENT:SURFACEPROPS',
#  'GROUNDHEATTRANSFER:BASEMENT:BLDGDATA',
#  'GROUNDHEATTRANSFER:BASEMENT:INTERIOR',
#  'GROUNDHEATTRANSFER:BASEMENT:COMBLDG',
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVSLAB',
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVAUTOGRID',
#  'PEOPLE',
#  'LIGHTS',
#  'ELECTRICEQUIPMENT',
#  'GASEQUIPMENT',
#  'ZONEINFILTRATION:EFFECTIVELEAKAGEAREA',
#  'ZONEVENTILATION:DESIGNFLOWRATE',
#  'EXTERIOR:LIGHTS',
#  'DESIGNSPECIFICATION:OUTDOORAIR',
#  'SIZING:ZONE',
#  'SIZING:SYSTEM',
#  'SIZING:PLANT',
#  'ZONECONTROL:THERMOSTAT',
#  'THERMOSTATSETPOINT:DUALSETPOINT',
#  'ZONEHVAC:ENERGYRECOVERYVENTILATOR',
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:NOREHEAT',
#  'ZONEHVAC:AIRDISTRIBUTIONUNIT',
#  'ZONEHVAC:EQUIPMENTLIST',
#  'ZONEHVAC:EQUIPMENTCONNECTIONS',
#  'FAN:ONOFF',
#  'COIL:COOLING:DX:SINGLESPEED',
#  'COIL:HEATING:FUEL',
#  'HEATEXCHANGER:AIRTOAIR:SENSIBLEANDLATENT',
#  'AIRLOOPHVAC:UNITARYHEATCOOL',
#  'AIRLOOPHVAC',
#  'AIRLOOPHVAC:ZONESPLITTER',
#  'AIRLOOPHVAC:SUPPLYPATH',
#  'AIRLOOPHVAC:ZONEMIXER',
#  'AIRLOOPHVAC:RETURNPATH',
#  'BRANCH',
#  'BRANCHLIST',
#  'CONNECTOR:SPLITTER',
#  'CONNECTOR:MIXER',
#  'CONNECTORLIST',
#  'NODELIST',
#  'OUTDOORAIR:NODE',
#  'OUTDOORAIR:NODELIST',
#  'PIPE:ADIABATIC',
#  'PUMP:VARIABLESPEED',
#  'WATERHEATER:MIXED',
#  'WATERHEATER:SIZING',
#  'PLANTLOOP',
#  'PLANTEQUIPMENTLIST',
#  'PLANTEQUIPMENTOPERATION:HEATINGLOAD',
#  'PLANTEQUIPMENTOPERATIONSCHEMES',
#  'AVAILABILITYMANAGER:SCHEDULED',
#  'AVAILABILITYMANAGERASSIGNMENTLIST',
#  'SETPOINTMANAGER:SCHEDULED',
#  'WATERUSE:EQUIPMENT',
#  'WATERUSE:CONNECTIONS',
#  'CURVE:QUADRATIC',
#  'CURVE:CUBIC',
#  'CURVE:EXPONENT',
#  'CURVE:BIQUADRATIC',
#  'OUTPUT:VARIABLEDICTIONARY',
#  'OUTPUT:CONSTRUCTIONS',
#  'OUTPUT:TABLE:SUMMARYREPORTS',
#  'OUTPUT:TABLE:MONTHLY',
#  'OUTPUTCONTROL:TABLE:STYLE']

# %%
#Select WH related object types - This step is manual. Copy object types from the unique_target_list
target_WH_list=['SIZING:PLANT',
                'BRANCH', 'BRANCHLIST', 
                'CONNECTOR:SPLITTER', 'CONNECTOR:MIXER', 'CONNECTORLIST',
                'NODELIST',
                'PIPE:ADIABATIC','PUMP:VARIABLESPEED',
                'WATERHEATER:MIXED','WATERHEATER:SIZING','PLANTLOOP',
                'PLANTEQUIPMENTLIST', 'PLANTEQUIPMENTOPERATION:HEATINGLOAD', 'PLANTEQUIPMENTOPERATIONSCHEMES',
                'SETPOINTMANAGER:SCHEDULED', 'WATERUSE:EQUIPMENT', 'WATERUSE:CONNECTIONS', 'CURVE:QUADRATIC', 'CURVE:CUBIC',
                'CURVE:EXPONENT', 'CURVE:BIQUADRATIC']

# %%
#review source file objects
source_obj=[]
for obj_type in sourceidf.idfobjects:
    for obj in sourceidf.idfobjects[obj_type]:
        source_obj.append(obj_type)

unique_source_list=[]        
[unique_source_list.append(x) for x in source_obj if x not in unique_source_list]
unique_source_list
# Out:
# ['VERSION',
#  'SIMULATIONCONTROL',
#  'BUILDING',
#  'SURFACECONVECTIONALGORITHM:INSIDE',
#  'TIMESTEP',
#  'SITE:LOCATION',
#  'SIZINGPERIOD:DESIGNDAY',
#  'RUNPERIOD',
#  'SITE:WATERMAINSTEMPERATURE',
#  'SCHEDULETYPELIMITS',
#  'SCHEDULE:DAY:HOURLY',
#  'SCHEDULE:WEEK:COMPACT',
#  'SCHEDULE:YEAR',
#  'SCHEDULE:COMPACT',
#  'SCHEDULE:CONSTANT',
#  'MATERIAL',
#  'MATERIAL:NOMASS',
#  'MATERIAL:AIRGAP',
#  'WINDOWMATERIAL:SIMPLEGLAZINGSYSTEM',
#  'WINDOWMATERIAL:GLAZING',
#  'WINDOWMATERIAL:BLIND',
#  'CONSTRUCTION',
#  'GLOBALGEOMETRYRULES',
#  'ZONE',
#  'BUILDINGSURFACE:DETAILED',
#  'WINDOW',
#  'DOOR',
#  'DOOR:INTERZONE',
#  'WINDOWSHADINGCONTROL',
#  'INTERNALMASS',
#  'SHADING:OVERHANG',
#  'GROUNDHEATTRANSFER:CONTROL',
#  'GROUNDHEATTRANSFER:SLAB:MATERIALS',
#  'GROUNDHEATTRANSFER:SLAB:MATLPROPS',
#  'GROUNDHEATTRANSFER:SLAB:BOUNDCONDS',
#  'GROUNDHEATTRANSFER:SLAB:BLDGPROPS',
#  'GROUNDHEATTRANSFER:SLAB:INSULATION',
#  'GROUNDHEATTRANSFER:SLAB:EQUIVALENTSLAB',
#  'GROUNDHEATTRANSFER:BASEMENT:SIMPARAMETERS',
#  'GROUNDHEATTRANSFER:BASEMENT:MATLPROPS',
#  'GROUNDHEATTRANSFER:BASEMENT:INSULATION',
#  'GROUNDHEATTRANSFER:BASEMENT:SURFACEPROPS',
#  'GROUNDHEATTRANSFER:BASEMENT:BLDGDATA',
#  'GROUNDHEATTRANSFER:BASEMENT:INTERIOR',
#  'GROUNDHEATTRANSFER:BASEMENT:COMBLDG',
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVSLAB',
#  'GROUNDHEATTRANSFER:BASEMENT:EQUIVAUTOGRID',
#  'PEOPLE',
#  'LIGHTS',
#  'ELECTRICEQUIPMENT',
#  'ZONEVENTILATION:DESIGNFLOWRATE',
#  'AIRFLOWNETWORK:MULTIZONE:COMPONENT:ZONEEXHAUSTFAN',
#  'EXTERIOR:LIGHTS',
#  'DESIGNSPECIFICATION:OUTDOORAIR',
#  'SIZING:ZONE',
#  'SIZING:SYSTEM',
#  'SIZING:PLANT',
#  'ZONECONTROL:THERMOSTAT',
#  'THERMOSTATSETPOINT:DUALSETPOINT',
#  'AIRTERMINAL:SINGLEDUCT:CONSTANTVOLUME:NOREHEAT',
#  'ZONEHVAC:AIRDISTRIBUTIONUNIT',
#  'ZONEHVAC:EQUIPMENTLIST',
#  'ZONEHVAC:EQUIPMENTCONNECTIONS',
#  'FAN:SYSTEMMODEL',
#  'FAN:ONOFF',
#  'FAN:ZONEEXHAUST',
#  'COIL:COOLING:DX:SINGLESPEED',
#  'COIL:HEATING:ELECTRIC',
#  'COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED',
#  'AIRLOOPHVAC:UNITARYHEATCOOL',
#  'AIRLOOPHVAC',
#  'AIRLOOPHVAC:ZONESPLITTER',
#  'AIRLOOPHVAC:SUPPLYPATH',
#  'AIRLOOPHVAC:ZONEMIXER',
#  'AIRLOOPHVAC:RETURNPATH',
#  'BRANCH',
#  'BRANCHLIST',
#  'CONNECTOR:SPLITTER',
#  'CONNECTOR:MIXER',
#  'CONNECTORLIST',
#  'NODELIST',
#  'PIPE:ADIABATIC',
#  'PIPE:INDOOR',
#  'PUMP:CONSTANTSPEED',
#  'WATERHEATER:STRATIFIED',
#  'WATERHEATER:SIZING',
#  'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER',
#  'PLANTLOOP',
#  'PLANTEQUIPMENTLIST',
#  'PLANTEQUIPMENTOPERATION:HEATINGLOAD',
#  'PLANTEQUIPMENTOPERATIONSCHEMES',
#  'AVAILABILITYMANAGER:SCHEDULED',
#  'AVAILABILITYMANAGERASSIGNMENTLIST',
#  'SETPOINTMANAGER:SCHEDULED',
#  'WATERUSE:EQUIPMENT',
#  'WATERUSE:CONNECTIONS',
#  'CURVE:QUADRATIC',
#  'CURVE:CUBIC',
#  'CURVE:BIQUADRATIC',
#  'OUTPUT:VARIABLEDICTIONARY',
#  'OUTPUT:CONSTRUCTIONS',
#  'OUTPUT:TABLE:SUMMARYREPORTS',
#  'OUTPUT:TABLE:MONTHLY',
#  'OUTPUTCONTROL:TABLE:STYLE',
#  'OUTPUT:METER']

# %%
#Select WH related object types - This step is manual
source_WH_list=['SIZING:PLANT', 
                'COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED',
                'FAN:SYSTEMMODEL',
                'PIPE:ADIABATIC', 'PIPE:INDOOR',
                'PUMP:CONSTANTSPEED',
                'WATERHEATER:STRATIFIED', 'WATERHEATER:SIZING', 'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER',
                'BRANCH', 'BRANCHLIST', 
                'CONNECTOR:SPLITTER', 'CONNECTOR:MIXER', 'CONNECTORLIST', 'NODELIST',
                'SETPOINTMANAGER:SCHEDULED',
                'PLANTLOOP','PLANTEQUIPMENTLIST','PLANTEQUIPMENTOPERATION:HEATINGLOAD','PLANTEQUIPMENTOPERATIONSCHEMES',
                'WATERUSE:EQUIPMENT', 'WATERUSE:CONNECTIONS',
                'CURVE:QUADRATIC', 'CURVE:CUBIC', 'CURVE:BIQUADRATIC']

# %%
#This is the list of WH realted object types that exist in the target file but not the source file. These objects are no longer needed.
WH_dif_list_target=[obj for obj in target_WH_list if obj not in source_WH_list]
WH_dif_list_target
# Out:
# ['PUMP:VARIABLESPEED', 'WATERHEATER:MIXED', 'CURVE:EXPONENT']

# %%
def keep_objtype_without_keyword(lst, keywords):
    return [item for item in lst if not any(keyword in item for keyword in keywords)]

# %%
#Create an exception list, this is user defined. Make sure the keyword(s) is/are capitalized. 
keep_keys=['CURVE']

delete_lst=keep_objtype_without_keyword(WH_dif_list_target, keep_keys)
delete_lst
# Out:
# ['PUMP:VARIABLESPEED', 'WATERHEATER:MIXED']

# %%
#Clear these unnecessary objects in the target file
for obj in delete_lst:
    targetidf.idfobjects[obj].clear()

# %% [markdown]
# # Edit Coil

# %%
#Identify WH related COIL object types exist in both files. 
#COIL needs to be capitalized as object types are capitalized in idf files.
COIL_target=[s for s in target_WH_list if "COIL" in s]
COIL_source=[s for s in source_WH_list if "COIL" in s]

print(COIL_target, COIL_source)
# Out:
# [] ['COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED']

# %% [markdown]
# Reme

# %%
lst_coil = targetidf.idfobjects['Coil:WaterHeating:AirToWaterHeatPump:Wrapped']
lst_coil
# Out:
# []

# %%
sourceidf.idfobjects['Coil:WaterHeating:AirToWaterHeatPump:Wrapped']
# Out:
# [
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil,          !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode,      !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode,     !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ]

# %%
for i in range(len(zones)):
    newclg = sourceidf.idfobjects['Coil:WaterHeating:AirToWaterHeatPump:Wrapped'][-1]
    targetidf.copyidfobject(newclg)
    lst_coil[-1].Name=newclg.Name+' '+zones[i]
    lst_coil[-1].Evaporator_Air_Inlet_Node_Name=newclg.Evaporator_Air_Inlet_Node_Name+' '+zones[i]
    lst_coil[-1].Evaporator_Air_Outlet_Node_Name=newclg.Evaporator_Air_Outlet_Node_Name+' '+zones[i]
        
lst_coil
# Out:
# [
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_FrontRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_FrontRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_FrontRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_FrontRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_FrontRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_FrontRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_FrontRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_FrontRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_FrontRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_BackRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_BackRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_BackRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_BackRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_BackRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_BackRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_BackRow_BottomFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_BackRow_BottomFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_BackRow_BottomFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_FrontRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_FrontRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_FrontRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_FrontRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_FrontRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_FrontRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_FrontRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_FrontRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_FrontRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_BackRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_BackRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_BackRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_BackRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_BackRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_BackRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_BackRow_MiddleFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_BackRow_MiddleFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_BackRow_MiddleFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_FrontRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_FrontRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_FrontRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_FrontRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_FrontRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_FrontRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_FrontRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_FrontRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_FrontRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit1_BackRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit1_BackRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit1_BackRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit2_BackRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit2_BackRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit2_BackRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ,
# Coil:WaterHeating:AirToWaterHeatPump:Wrapped,
#     HPWHPlantDXCoil living_unit3_BackRow_TopFloor,    !- Name
#     2349.6,                   !- Rated Heating Capacity
#     2.4,                      !- Rated COP
#     0.981,                    !- Rated Sensible Heat Ratio
#     19.72,                    !- Rated Evaporator Inlet Air DryBulb Temperature
#     13.5,                     !- Rated Evaporator Inlet Air WetBulb Temperature
#     48.89,                    !- Rated Condenser Water Temperature
#     0.189,                    !- Rated Evaporator Air Flow Rate
#     Yes,                      !- Evaporator Fan Power Included in Rated COP
#     HPPlantAirInletNode living_unit3_BackRow_TopFloor,    !- Evaporator Air Inlet Node Name
#     HPPlantAirOutletNode living_unit3_BackRow_TopFloor,    !- Evaporator Air Outlet Node Name
#     0,                        !- Crankcase Heater Capacity
#     10,                       !- Maximum Ambient Temperature for Crankcase Heater Operation
#     WetBulbTemperature,       !- Evaporator Air Temperature Type for Curve Objects
#     HPWH-Htg-Cap-fT,          !- Heating Capacity Function of Temperature Curve Name
#     ,                         !- Heating Capacity Function of Air Flow Fraction Curve Name
#     HPWH-Htg-COP-fT;          !- Heating COP Function of Temperature Curve Name
# ]

# %% [markdown]
# # Edit Pump

# %%
#Identify WH related PUMP object types exist in both files. 
#PUMP needs to be capitalized as object types are capitalized in idf files.
PUMP_target=[s for s in target_WH_list if "PUMP:" in s]
PUMP_source=[s for s in source_WH_list if "PUMP:" in s]

print(PUMP_target, PUMP_source)
# Out:
# ['PUMP:VARIABLESPEED'] ['COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED', 'PUMP:CONSTANTSPEED', 'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER']

# %% [markdown]
# Here we can ignore the non-pump object types. Since 'Pump:VariableSpeed' only exists in the target file, it's already cleared, therefore we only need to add 'Pump:ConstantSpeed' from source to target file. If a variable-speed pump is preferred, it can be either addressed after the whole electrification modeling, or addressed within the souce file - then we need to change the following object type in the code.

# %%
lst_pump = targetidf.idfobjects['Pump:ConstantSpeed']
lst_pump
# Out:
# []

# %%
sourceidf.idfobjects['Pump:ConstantSpeed']
# Out:
# [
# Pump:ConstantSpeed,
#     SWHSys1 Pump,             !- Name
#     SWHSys1 Supply Inlet Node,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ]

# %%
for i in range(len(zones)):
    newclg = sourceidf.idfobjects['Pump:ConstantSpeed'][-1]
    targetidf.copyidfobject(newclg)
    lst_pump[-1].Name=newclg.Name+' '+zones[i]
    lst_pump[-1].Inlet_Node_Name=newclg.Inlet_Node_Name+' '+zones[i]
    lst_pump[-1].Outlet_Node_Name=newclg.Outlet_Node_Name+' '+zones[i]
        
lst_pump
# Out:
# [
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_FrontRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_FrontRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_FrontRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_FrontRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_FrontRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_FrontRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_BackRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_BackRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_BackRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_BackRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_BackRow_BottomFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_BottomFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_BackRow_BottomFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_FrontRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_FrontRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_FrontRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_FrontRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_FrontRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_FrontRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_BackRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_BackRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_BackRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_BackRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_BackRow_MiddleFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_MiddleFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_BackRow_MiddleFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_FrontRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_FrontRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_FrontRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_FrontRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_FrontRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_FrontRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit1_BackRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_BackRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit2_BackRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_BackRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ,
# Pump:ConstantSpeed,
#     SWHSys1 Pump living_unit3_BackRow_TopFloor,    !- Name
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_TopFloor,    !- Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_BackRow_TopFloor,    !- Outlet Node Name
#     AUTOSIZE,                 !- Design Flow Rate
#     0.001,                    !- Design Pump Head
#     AUTOSIZE,                 !- Design Power Consumption
#     1,                        !- Motor Efficiency
#     0,                        !- Fraction of Motor Inefficiencies to Fluid Stream
#     Intermittent;             !- Pump Control Type
# ]

# %% [markdown]
# # Edit Fan

# %%
#Identify WH related FAN object types exist in both files. 
#FAN needs to be capitalized as object types are capitalized in idf files.
FAN_target=[s for s in target_WH_list if "FAN:" in s]
FAN_source=[s for s in source_WH_list if "FAN:" in s]

print(FAN_target, FAN_source)
# Out:
# [] ['FAN:SYSTEMMODEL']

# %%
lst_fan=targetidf.idfobjects['Fan:SystemModel']
lst_fan
# Out:
# []

# %%
sourceidf.idfobjects['Fan:SystemModel']
# Out:
# [
# Fan:SystemModel,
#     HPWHPlantFan,             !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode,     !- Air Inlet Node Name
#     HPPlantFanAirOutletNode,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ]

# %%
for i in range(len(zones)):
    newclg = sourceidf.idfobjects['Fan:SystemModel'][-1]
    targetidf.copyidfobject(newclg)
    lst_fan[-1].Name=newclg.Name+' '+zones[i]
    lst_fan[-1].Air_Inlet_Node_Name=newclg.Air_Inlet_Node_Name+' '+zones[i]
    lst_fan[-1].Air_Outlet_Node_Name=newclg.Air_Outlet_Node_Name+' '+zones[i]
        
lst_fan
# Out:
# [
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_FrontRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_FrontRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_FrontRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_BackRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_BackRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_BackRow_BottomFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_BottomFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_FrontRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_FrontRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_FrontRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_BackRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_BackRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_BackRow_MiddleFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_MiddleFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_FrontRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_FrontRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_FrontRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit1_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit1_BackRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit2_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit2_BackRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ,
# Fan:SystemModel,
#     HPWHPlantFan living_unit3_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     HPPlantAirOutletNode living_unit3_BackRow_TopFloor,    !- Air Inlet Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_TopFloor,    !- Air Outlet Node Name
#     0.2279,                   !- Design Maximum Air Flow Rate
#     Discrete,                 !- Speed Control Method
#     0,                        !- Electric Power Minimum Flow Rate Fraction
#     65,                       !- Design Pressure Rise
#     1,                        !- Motor Efficiency
#     0,                        !- Motor In Air Stream Fraction
#     AUTOSIZE,                 !- Design Electric Power Consumption
#     TotalEfficiencyAndPressure,    !- Design Power Sizing Method
#     ,                         !- Electric Power Per Unit Flow Rate
#     ,                         !- Electric Power Per Unit Flow Rate Per Unit Pressure
#     0.1722;                   !- Fan Total Efficiency
# ]

# %% [markdown]
# # Edit WH

# %%
#Identify WH related WATERHEATER object types exist in both files. 
#WATERHEATER needs to be capitalized as object types are capitalized in idf files.
WH_target=[s for s in target_WH_list if "WATERHEATER" in s]
WH_source=[s for s in source_WH_list if "WATERHEATER" in s]

print(WH_target, WH_source)
# Out:
# ['WATERHEATER:MIXED', 'WATERHEATER:SIZING'] ['WATERHEATER:STRATIFIED', 'WATERHEATER:SIZING', 'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER']

# %% [markdown]
# None of the WaterHeater object types in the target file are in the source file, implying simple copy-paste - target WaterHeater object types have been cleared at the beginning.

# %%
lst_WH = targetidf.idfobjects['WaterHeater:Stratified']
lst_WH
# Out:
# []

# %%
sourceidf.idfobjects['WaterHeater:Stratified']
# Out:
# [
# WaterHeater:Stratified,
#     Water Heater Tank,        !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ]

# %%
for i in range(len(zones)):
    newclg = sourceidf.idfobjects['WaterHeater:Stratified'][-1]
    targetidf.copyidfobject(newclg)
    lst_WH[-1].Name=newclg.Name+' '+zones[i]
    lst_WH[-1].Use_Side_Inlet_Node_Name=newclg.Use_Side_Inlet_Node_Name+' '+zones[i]
    lst_WH[-1].Use_Side_Outlet_Node_Name=newclg.Use_Side_Outlet_Node_Name+' '+zones[i]
        
lst_WH
# Out:
# [
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_FrontRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_FrontRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_FrontRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_BackRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_BackRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_BackRow_BottomFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_BottomFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_BottomFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_FrontRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_FrontRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_FrontRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_BackRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_BackRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_BackRow_MiddleFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_MiddleFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_MiddleFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_FrontRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_FrontRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_FrontRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit1_BackRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit2_BackRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ,
# WaterHeater:Stratified,
#     Water Heater Tank living_unit3_BackRow_TopFloor,    !- Name
#     Water Heater,             !- EndUse Subcategory
#     0.287691,                 !- Tank Volume
#     1.594,                    !- Tank Height
#     VerticalCylinder,         !- Tank Shape
#     ,                         !- Tank Perimeter
#     82.2222,                  !- Maximum Temperature Limit
#     MasterSlave,              !- Heater Priority Control
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 1 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 1 Deadband Temperature Difference
#     4500,                     !- Heater 1 Capacity
#     1.129,                    !- Heater 1 Height
#     SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Heater 2 Setpoint Temperature Schedule Name
#     18.5,                     !- Heater 2 Deadband Temperature Difference
#     0,                        !- Heater 2 Capacity
#     0.266,                    !- Heater 2 Height
#     Electricity,              !- Heater Fuel Type
#     1,                        !- Heater Thermal Efficiency
#     8.3,                      !- Off Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- Off Cycle Parasitic Fuel Type
#     0,                        !- Off Cycle Parasitic Heat Fraction to Tank
#     1,                        !- Off Cycle Parasitic Height
#     8.3,                      !- On Cycle Parasitic Fuel Consumption Rate
#     Electricity,              !- On Cycle Parasitic Fuel Type
#     0,                        !- On Cycle Parasitic Heat Fraction to Tank
#     1,                        !- On Cycle Parasitic Height
#     Schedule,                 !- Ambient Temperature Indicator
#     SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Ambient Temperature Schedule Name
#     ,                         !- Ambient Temperature Zone Name
#     ,                         !- Ambient Temperature Outdoor Air Node Name
#     0.7878,                   !- Uniform Skin Loss Coefficient per Unit Area to Ambient Temperature
#     1,                        !- Skin Loss Fraction to Zone
#     ,                         !- Off Cycle Flue Loss Coefficient to Ambient Temperature
#     1,                        !- Off Cycle Flue Loss Fraction to Zone
#     ,                         !- Peak Use Flow Rate
#     ,                         !- Use Flow Rate Fraction Schedule Name
#     ,                         !- Cold Water Supply Temperature Schedule Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_TopFloor,    !- Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_TopFloor,    !- Use Side Outlet Node Name
#     1,                        !- Use Side Effectiveness
#     0,                        !- Use Side Inlet Height
#     autocalculate,            !- Use Side Outlet Height
#     ,                         !- Source Side Inlet Node Name
#     ,                         !- Source Side Outlet Node Name
#     ,                         !- Source Side Effectiveness
#     ,                         !- Source Side Inlet Height
#     ,                         !- Source Side Outlet Height
#     Fixed,                    !- Inlet Mode
#     autosize,                 !- Use Side Design Flow Rate
#     autosize,                 !- Source Side Design Flow Rate
#     1.5,                      !- Indirect Water Heating Recovery Time
#     12;                       !- Number of Nodes
# ]

# %% [markdown]
# # Edit HPWH

# %% [markdown]
# Now we have coil, fan, pump and water heater, we can now put them all together in the heat pump water heater.

# %%
lst_HPWH = targetidf.idfobjects['WaterHeater:HeatPump:WrappedCondenser']
lst_HPWH
# Out:
# []

# %%
sourceidf.idfobjects['WaterHeater:HeatPump:WrappedCondenser']
# Out:
# [
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode,      !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank,        !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil,          !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan,             !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ]

# %%
for i in range(len(zones)):
    newclg = sourceidf.idfobjects['WaterHeater:HeatPump:WrappedCondenser'][-1]
    targetidf.copyidfobject(newclg)
    lst_HPWH[-1].Name=newclg.Name+' '+zones[i]
    
    lst_HPWH[-1].Outdoor_Air_Node_Name=newclg.Outdoor_Air_Node_Name+' '+zones[i]
    lst_HPWH[-1].Exhaust_Air_Node_Name=newclg.Exhaust_Air_Node_Name+' '+zones[i]
    
    lst_HPWH[-1].Tank_Name=lst_WH[i].Name #Connect to the corresponding water heater
    lst_HPWH[-1].Tank_Use_Side_Inlet_Node_Name=lst_WH[i].Use_Side_Inlet_Node_Name #Connect to the inlet node of the water heater
    lst_HPWH[-1].Tank_Use_Side_Outlet_Node_Name=lst_WH[i].Use_Side_Outlet_Node_Name #Connect to the outlet node of the water heater
    
    lst_HPWH[-1].DX_Coil_Name=lst_coil[i].Name #Connect to the corresponding DX coil
    
    lst_HPWH[-1].Fan_Name=lst_fan[i].Name #Connect to the corresponding system model fan

lst_HPWH
# Out:
# [
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_FrontRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_FrontRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_FrontRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_FrontRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_FrontRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_FrontRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_FrontRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_FrontRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_FrontRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_FrontRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_FrontRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_FrontRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_BackRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_BackRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_BackRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_BackRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_BackRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_BackRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_BackRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_BackRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_BackRow_BottomFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_BackRow_BottomFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_BottomFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_BackRow_BottomFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_BottomFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_BottomFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_BackRow_BottomFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_BackRow_BottomFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_FrontRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_FrontRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_FrontRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_FrontRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_FrontRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_FrontRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_FrontRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_FrontRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_FrontRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_FrontRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_FrontRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_FrontRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_BackRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_BackRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_BackRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_BackRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_BackRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_BackRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_BackRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_BackRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_BackRow_MiddleFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_BackRow_MiddleFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_MiddleFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_BackRow_MiddleFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_MiddleFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_MiddleFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_BackRow_MiddleFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_BackRow_MiddleFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_FrontRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_FrontRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_FrontRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_FrontRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_FrontRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_FrontRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_FrontRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_FrontRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_FrontRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_FrontRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_FrontRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_FrontRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_FrontRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_FrontRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_FrontRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit1_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit1_BackRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit1_BackRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit1_BackRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit1_BackRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit1_BackRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit2_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit2_BackRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit2_BackRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit2_BackRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit2_BackRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit2_BackRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ,
# WaterHeater:HeatPump:WrappedCondenser,
#     PlantHeatPumpWaterHeater living_unit3_BackRow_TopFloor,    !- Name
#     always_avail,             !- Availability Schedule Name
#     PlantHPWHTempSch,         !- Compressor Setpoint Temperature Schedule Name
#     3.89,                     !- Dead Band Temperature Difference
#     0.0664166667,             !- Condenser Bottom Location
#     0.8634166667,             !- Condenser Top Location
#     0.2279,                   !- Evaporator Air Flow Rate
#     OutdoorAirOnly,           !- Inlet Air Configuration
#     ,                         !- Air Inlet Node Name
#     ,                         !- Air Outlet Node Name
#     HPPlantAirInletNode living_unit3_BackRow_TopFloor,    !- Outdoor Air Node Name
#     HPPlantFanAirOutletNode living_unit3_BackRow_TopFloor,    !- Exhaust Air Node Name
#     ,                         !- Inlet Air Temperature Schedule Name
#     ,                         !- Inlet Air Humidity Schedule Name
#     ,                         !- Inlet Air Zone Name
#     WaterHeater:Stratified,    !- Tank Object Type
#     Water Heater Tank living_unit3_BackRow_TopFloor,    !- Tank Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_TopFloor,    !- Tank Use Side Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_TopFloor,    !- Tank Use Side Outlet Node Name
#     Coil:WaterHeating:AirToWaterHeatPump:Wrapped,    !- DX Coil Object Type
#     HPWHPlantDXCoil living_unit3_BackRow_TopFloor,    !- DX Coil Name
#     7.2,                      !- Minimum Inlet Air Temperature for Compressor Operation
#     48.89,                    !- Maximum Inlet Air Temperature for Compressor Operation
#     Outdoors,                 !- Compressor Location
#     ,                         !- Compressor Ambient Temperature Schedule Name
#     Fan:SystemModel,          !- Fan Object Type
#     HPWHPlantFan living_unit3_BackRow_TopFloor,    !- Fan Name
#     DrawThrough,              !- Fan Placement
#     0,                        !- On Cycle Parasitic Electric Load
#     0,                        !- Off Cycle Parasitic Electric Load
#     ,                         !- Parasitic Heat Rejection Location
#     ,                         !- Inlet Air Mixer Node Name
#     ,                         !- Outlet Air Splitter Node Name
#     ,                         !- Inlet Air Mixer Schedule Name
#     MutuallyExclusive,        !- Tank Element Control Logic
#     1.262,                    !- Control Sensor 1 Height In Stratified Tank
#     0.75,                     !- Control Sensor 1 Weight
#     0.464;                    !- Control Sensor 2 Height In Stratified Tank
# ]

# %% [markdown]
# ## Edit WaterHeater:Sizing

# %%
lst_WHSizing=targetidf.idfobjects['WaterHeater:Sizing']
lst_WHSizing
# Out:
# [
# WaterHeater:Sizing,
#     Water Heater_unit1_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit1_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit1_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit1_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit1_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit1_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit2_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater_unit3_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ]

# %%
sourceidf.idfobjects['WaterHeater:Sizing']
# Out:
# [
# WaterHeater:Sizing,
#     Water Heater Tank,        !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     3,                        !- Number of Bedrooms
#     3;                        !- Number of Bathrooms
# ]

# %% [markdown]
# To properly size WHs, we need to keep the number of bedrooms and bathrooms in the target file. Therefore, instead of clearing the objects from target file, we simply replace the WaterHeater Name.

# %%
for i in range(len(zones)):
    lst_WHSizing[i].WaterHeater_Name=lst_WH[i].Name

lst_WHSizing
# Out:
# [
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_FrontRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_BackRow_BottomFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_FrontRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_BackRow_MiddleFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_FrontRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit1_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit2_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ,
# WaterHeater:Sizing,
#     Water Heater Tank living_unit3_BackRow_TopFloor,    !- WaterHeater Name
#     ResidentialHUD-FHAMinimum,    !- Design Mode
#     ,                         !- Time Storage Can Meet Peak Draw
#     ,                         !- Time for Tank Recovery
#     ,                         !- Nominal Tank Volume for Autosizing Plant Connections
#     2,                        !- Number of Bedrooms
#     2;                        !- Number of Bathrooms
# ]

# %% [markdown]
# # Edit PlantEquipment

# %%
#Identify WH related PLANTEQUIPMENT object types exist in both files. 
#PLANTEQUIPMENT needs to be capitalized as object types are capitalized in idf files.
PE_target=[s for s in target_WH_list if "PLANTEQUIPMENT" in s]
PE_source=[s for s in source_WH_list if "PLANTEQUIPMENT" in s]

print(PE_target, PE_source)
# Out:
# ['PLANTEQUIPMENTLIST', 'PLANTEQUIPMENTOPERATION:HEATINGLOAD', 'PLANTEQUIPMENTOPERATIONSCHEMES'] ['PLANTEQUIPMENTLIST', 'PLANTEQUIPMENTOPERATION:HEATINGLOAD', 'PLANTEQUIPMENTOPERATIONSCHEMES']

# %% [markdown]
# Identical object types for both files, so we will replace the objects in each type one by one.

# %% [markdown]
# ### Plant Equipment List

# %% [markdown]
# With all the HPWH set up, we can now put the heat pump and water heater together in the PlantEquipmentList.

# %%
lst_PEqp = targetidf.idfobjects['PlantEquipmentList']
lst_PEqp
# Out:
# [
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_FrontRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_FrontRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_FrontRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_BackRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_BackRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_BackRow_BottomFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_BackRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_BackRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_BackRow_MiddleFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_FrontRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_FrontRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_FrontRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit1_BackRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit1_BackRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit2_BackRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit2_BackRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     DHW Plant Equipment_unit3_BackRow_TopFloor,    !- Name
#     WaterHeater:Mixed,        !- Equipment 1 Object Type
#     Water Heater_unit3_BackRow_TopFloor;    !- Equipment 1 Name
# ]

# %%
sourceidf.idfobjects['PlantEquipmentList']
# Out:
# [
# PlantEquipmentList,
#     SWHSys1 Equipment List,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater;    !- Equipment 1 Name
# ]

# %% [markdown]
# Since the original PlantEquipmentList uses a different type of water heater, we need to clear the existing plant equipment list then add the new objects.

# %%
targetidf.idfobjects['PlantEquipmentList'].clear()

for i in range(len(zones)):
    new=sourceidf.idfobjects['PlantEquipmentList'][0]
    targetidf.copyidfobject(new)
    lst_PEqp[-1].Name=new.Name+' '+zones[i]
    lst_PEqp[-1].Equipment_1_Name=lst_HPWH[i].Name #Connect to the corresponding HPWH

lst_PEqp
# Out:
# [
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_FrontRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_FrontRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_FrontRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_BackRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_BackRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_BackRow_BottomFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_BottomFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_FrontRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_BackRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_BackRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_BackRow_MiddleFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_MiddleFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_FrontRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_FrontRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_FrontRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit1_BackRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit2_BackRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_TopFloor;    !- Equipment 1 Name
# ,
# PlantEquipmentList,
#     SWHSys1 Equipment List living_unit3_BackRow_TopFloor,    !- Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Equipment 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_TopFloor;    !- Equipment 1 Name
# ]

# %% [markdown]
# ### Plant Equipment Operation

# %%
lst_POEqpHL=targetidf.idfobjects['PlantEquipmentOperation:HeatingLoad']
lst_POEqpHL
# Out:
# [
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit1_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit1_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit2_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit2_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     DHW Control Scheme_unit3_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     DHW Plant Equipment_unit3_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ]

# %%
sourceidf.idfobjects['PlantEquipmentOperation:HeatingLoad']
# Out:
# [
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List;    !- Range 1 Equipment List Name
# ]

# %%
targetidf.idfobjects['PlantEquipmentOperation:HeatingLoad'].clear()

for i in range(len(zones)):
    new=sourceidf.idfobjects['PlantEquipmentOperation:HeatingLoad'][0]
    targetidf.copyidfobject(new)
    lst_POEqpHL[-1].Name=new.Name+' '+zones[i]
    lst_POEqpHL[-1].Range_1_Equipment_List_Name=lst_PEqp[i].Name # Connect to the corresponding Plant Equipment List

targetidf.idfobjects['PlantEquipmentOperation:HeatingLoad']
# Out:
# [
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_FrontRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_FrontRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_BackRow_BottomFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_BackRow_BottomFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_FrontRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_FrontRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_BackRow_MiddleFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_BackRow_MiddleFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_FrontRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_FrontRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit1_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit1_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit2_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit2_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ,
# PlantEquipmentOperation:HeatingLoad,
#     SWHSys1 Operation Scheme living_unit3_BackRow_TopFloor,    !- Name
#     0,                        !- Load Range 1 Lower Limit
#     1000000000000000,         !- Load Range 1 Upper Limit
#     SWHSys1 Equipment List living_unit3_BackRow_TopFloor;    !- Range 1 Equipment List Name
# ]

# %% [markdown]
# ### Plant Equipment Operation Schemes

# %%
lst_POEqpSch=targetidf.idfobjects['PlantEquipmentOperationSchemes']
lst_POEqpSch
# Out:
# [
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit1_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit1_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit2_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit2_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     DHW Loop Operation_unit3_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     DHW Control Scheme_unit3_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ]

# %%
sourceidf.idfobjects['PlantEquipmentOperationSchemes']
# Out:
# [
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ]

# %%
targetidf.idfobjects['PlantEquipmentOperationSchemes'].clear()

for i in range(len(zones)):
    new=sourceidf.idfobjects['PlantEquipmentOperationSchemes'][0]
    targetidf.copyidfobject(new)
    lst_POEqpSch[-1].Name=new.Name+' '+zones[i]
    lst_POEqpSch[-1].Control_Scheme_1_Name=lst_POEqpHL[i].Name #Connect to the corresponding Plant Equipment Operation Heating Load
    
lst_POEqpSch
# Out:
# [
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_FrontRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_BottomFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_BackRow_BottomFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_FrontRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_MiddleFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_BackRow_MiddleFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_FrontRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit1_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit2_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ,
# PlantEquipmentOperationSchemes,
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_TopFloor,    !- Name
#     PlantEquipmentOperation:HeatingLoad,    !- Control Scheme 1 Object Type
#     SWHSys1 Operation Scheme living_unit3_BackRow_TopFloor,    !- Control Scheme 1 Name
#     always_avail;             !- Control Scheme 1 Schedule Name
# ]

# %% [markdown]
# # Edit Pipe

# %% [markdown]
# Although Pipe is part of the plant system, without touching the configurations of water use equipment, pipes are better to be left untouched, as they are not affected by the water heater replacement.

# %% [markdown]
# # Edit Branch

# %% [markdown]
# Unlike electrifying air-side system, when electrifying water-side system, we prefer branches to be touched at a minimum level as there are no significant configuration changes. The impact of electrifying water heater on branches is the change of component type and the associated nodes within the existing configurations.

# %%
def find_Water_branch(keywords, idf, obj_type):
    lst_objtype=idf.idfobjects[obj_type] #Pull out all branches into a list for an idf
    lst_objtype_name=[]
    
    #check if any of the keywords exist in the branch name
    for i in range(len(lst_objtype)):
        component_type=lst_objtype[i].Component_1_Object_Type
        if any(keyword in component_type for keyword in keywords):
            lst_objtype_name.append(True)
        else:
            lst_objtype_name.append(False)
    
    #Get a list of indices of AC branches in the idf
    lst_Water_objtype_idx=[i for i,x in enumerate(lst_objtype_name) if x] 
    return lst_Water_objtype_idx

# %%
lst_branch=targetidf.idfobjects['Branch']

# %% [markdown]
# 1. Swithc existing WH branches with the new HPWH.

# %%
key_WH=['WaterHeater']
lst_target_WH_branch_idx=find_Water_branch(key_WH,targetidf,'Branch')
lst_target_WH_branch_idx
# Out:
# [27,
#  37,
#  47,
#  57,
#  67,
#  77,
#  87,
#  97,
#  107,
#  117,
#  127,
#  137,
#  147,
#  157,
#  167,
#  177,
#  187,
#  197]

# %%
len(lst_target_WH_branch_idx)==len(lst_HPWH)
# Out:
# True

# %%
for i in range(len(lst_HPWH)):
    WH_branch_idx=lst_target_WH_branch_idx[i]
    lst_branch[WH_branch_idx].Component_1_Object_Type='WaterHeater:HeatPump:WrappedCondenser'
    lst_branch[WH_branch_idx].Component_1_Name=lst_HPWH[i].Name
    lst_branch[WH_branch_idx].Component_1_Inlet_Node_Name=lst_HPWH[i].Tank_Use_Side_Inlet_Node_Name
    lst_branch[WH_branch_idx].Component_1_Outlet_Node_Name=lst_HPWH[i].Tank_Use_Side_Outlet_Node_Name


lst_branch
# Out:
# [
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
# ...
#     Water Sink Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Mains Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Mains Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:VariableSpeed,       !- Component 1 Object Type
#     Mains Pressure_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Mains Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Pressure Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ]

# %% [markdown]
# 2. Switch existing pump branches with new pumps

# %%
key_pump=['Pump:VariableSpeed']
lst_target_pump_branch_idx=find_Water_branch(key_pump,targetidf,'Branch')
lst_target_pump_branch_idx
# Out:
# [18,
#  28,
#  38,
#  48,
#  58,
#  68,
#  78,
#  88,
#  98,
#  108,
#  118,
#  128,
#  138,
#  148,
#  158,
#  168,
#  178,
#  188]

# %%
len(lst_target_pump_branch_idx)==len(lst_pump)
# Out:
# True

# %%
for i in range(len(lst_pump)):
    pump_branch_idx=lst_target_pump_branch_idx[i]
    lst_branch[pump_branch_idx].Component_1_Object_Type='Pump:ConstantSpeed'
    lst_branch[pump_branch_idx].Component_1_Name=lst_pump[i].Name
    lst_branch[pump_branch_idx].Component_1_Inlet_Node_Name=lst_pump[i].Inlet_Node_Name
    lst_branch[pump_branch_idx].Component_1_Outlet_Node_Name=lst_pump[i].Outlet_Node_Name

lst_branch
# Out:
# [
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_MiddleFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Air Loop Main Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     AirLoopHVAC:UnitaryHeatCool,    !- Component 1 Object Type
#     ACandF_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Air Loop Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Air loop outlet node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_FrontRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_BackRow_BottomFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_BottomFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_BottomFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_BottomFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_MiddleFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_MiddleFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_MiddleFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_MiddleFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
# ...
# ,
# Branch,
#     Water Shower Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_FrontRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_FrontRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_FrontRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_FrontRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit1_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit1_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit1_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit1_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit1_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit1_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit2_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit2_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit2_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit2_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit2_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit2_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Inlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pump:ConstantSpeed,       !- Component 1 Object Type
#     SWHSys1 Pump living_unit3_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNodeviaConnector living_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Supply Outlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Supply Outlet Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     DHW Supply Outlet Pipe Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     DHW Demand Inlet Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     DHW Demand Inlet Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     DHW Demand Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     DHW Demand Inlet Pipe Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Sink Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Sinks_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Sink Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Sink outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Shower Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Showers_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Shower Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water Shower Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water ClothesWasher Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW ClothesWasher_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water ClothesWasher Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water ClothesWasher Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Dishwasher Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW DishWasher_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water DishWasher Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water DishWasher outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Bath Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterUse:Connections,     !- Component 1 Object Type
#     DHW Baths_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Water Bath Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Water bath Outlet Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Mains Makeup Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     Pipe:Adiabatic,           !- Component 1 Object Type
#     Mains Makeup Pipe_unit3_BackRow_TopFloor,    !- Component 1 Name
#     Mains Makeup Pipe Inlet Node_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ,
# Branch,
#     Water Heater Branch_unit3_BackRow_TopFloor,    !- Name
#     ,                         !- Pressure Drop Curve Name
#     WaterHeater:HeatPump:WrappedCondenser,    !- Component 1 Object Type
#     PlantHeatPumpWaterHeater living_unit3_BackRow_TopFloor,    !- Component 1 Name
#     SWHSys1 Pump-SWHSys1 Water HeaterNode living_unit3_BackRow_TopFloor,    !- Component 1 Inlet Node Name
#     SWHSys1 Supply Equipment Outlet Node living_unit3_BackRow_TopFloor;    !- Component 1 Outlet Node Name
# ]

# %% [markdown]
# # BranchList, Connector, Splitter and Mixer

# %% [markdown]
# Again, since there are no major configuration changes in the water system, these object types can be left untouched.

# %% [markdown]
# # Edit Plant Lopp

# %%
#Identify WH related PLANTLOOP object types exist in both files. 
#PLANTLOOP needs to be capitalized as object types are capitalized in idf files.
PLANTLOOP_target=[s for s in target_WH_list if "PLANTLOOP" in s]
PLANTLOOP_source=[s for s in source_WH_list if "PLANTLOOP" in s]

print(PLANTLOOP_target, PLANTLOOP_source)
# Out:
# ['PLANTLOOP'] ['PLANTLOOP']

# %%
lst_PL = targetidf.idfobjects['PlantLoop']
lst_PL
# Out:
# [
# PlantLoop,
#     DHW Loop_unit1_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit1_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit1_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit2_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit2_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     DHW Loop Operation_unit3_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     Mains Inlet Node_unit3_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ]

# %% [markdown]
# For PlantLoop objects, we need to update the name of plant equipment operation scheme and the plant side inlet node name, which are affected by the new pumps and the new water heaters. Other things can remain untouched.

# %%
for i in range(len(lst_PL)):
    lst_PL[i].Plant_Equipment_Operation_Scheme_Name=lst_POEqpSch[i].Name
    lst_PL[i].Plant_Side_Inlet_Node_Name=lst_pump[i].Inlet_Node_Name

lst_PL
# Out:
# [
# PlantLoop,
#     DHW Loop_unit1_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_BottomFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_BottomFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_BottomFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_BottomFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_BottomFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_BottomFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_BottomFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_BottomFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_BottomFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_BottomFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_MiddleFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_MiddleFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_MiddleFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_MiddleFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_MiddleFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_MiddleFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_MiddleFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_MiddleFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_MiddleFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_MiddleFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_MiddleFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_FrontRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_FrontRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_FrontRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_FrontRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_FrontRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_FrontRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_FrontRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_FrontRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_FrontRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_FrontRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_FrontRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit1_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit1_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit1_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit1_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit1_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit1_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit1_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit1_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit1_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit1_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit2_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit2_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit2_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit2_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit2_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit2_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit2_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit2_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit2_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit2_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ,
# PlantLoop,
#     DHW Loop_unit3_BackRow_TopFloor,    !- Name
#     Water,                    !- Fluid Type
#     ,                         !- User Defined Fluid Type
#     SWHSys1 Loop Operation Scheme List living_unit3_BackRow_TopFloor,    !- Plant Equipment Operation Scheme Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor,    !- Loop Temperature Setpoint Node Name
#     100,                      !- Maximum Loop Temperature
#     0,                        !- Minimum Loop Temperature
#     autosize,                 !- Maximum Loop Flow Rate
#     0,                        !- Minimum Loop Flow Rate
#     autocalculate,            !- Plant Loop Volume
#     SWHSys1 Supply Inlet Node living_unit3_BackRow_TopFloor,    !- Plant Side Inlet Node Name
#     DHW Supply Outlet Node_unit3_BackRow_TopFloor,    !- Plant Side Outlet Node Name
#     DHW Supply Branches_unit3_BackRow_TopFloor,    !- Plant Side Branch List Name
#     DHW Supply Connectors_unit3_BackRow_TopFloor,    !- Plant Side Connector List Name
#     DHW Demand Inlet Node_unit3_BackRow_TopFloor,    !- Demand Side Inlet Node Name
#     Mains Makeup Node_unit3_BackRow_TopFloor,    !- Demand Side Outlet Node Name
#     DHW Demand Branches_unit3_BackRow_TopFloor,    !- Demand Side Branch List Name
#     DHW Demand Connectors_unit3_BackRow_TopFloor,    !- Demand Side Connector List Name
#     Optimal;                  !- Load Distribution Scheme
# ]

# %% [markdown]
# For reference, following fieldnames from different objects should be aligned:

# %% [markdown]
# 1. PlantLoop.Plant_Side_Inlet_Node_Name =
#    Pump.inlet_node_name =
#    Branch(Supply Inlet Branch).Component_1_Inlet_Node_Name

# %% [markdown]
# 2. PlantLoop.Plant_Side_Outlet_Node_Name=PlantLoop.Loop_Temperature_Setpoint_Node_Name=SetpointManager.Setpoint_Node_or_NodeList_Name=Pipe(supply outlet pipe).Outlet_Node_Name=Branch(Supply Outlet Brach).Component_1_Outlet_Node_Name

# %% [markdown]
# 3. PlantLoop.Plant_Side_Branch_List_Name=BranchList(Supply Branches).Name

# %% [markdown]
# 4. PlantLoop.Demand_Side_Inlet_Node_Name=Pipe(Demand Inlet Pipe).Inlet_Node_Name=Branch(Demand Inlet Branch).Component_1_Inlet_Node_Name

# %% [markdown]
# 5. PlantLoop.Demand_Side_Outlet_Node_Name=Branch(Mains Makeup Branch).Component_1_Outlet_Node_Name

# %% [markdown]
# # Edit Sizing:Plant

# %% [markdown]
# Since we didn't change the plant loop names, Sizing:Plant object should also remain untouched

# %% [markdown]
# # Curves

# %% [markdown]
# Curves and Schedules are different from the previous object types. We want to make sure all the new curves and schedules are migrated properly to avoid any errors, but also want to avoid duplicated names in Curves and Schedules. For curves, the safest way to do this is to duplicate all the Curves in the source file and then check any duplicated names exist. We will then drop the object with the duplicated name in the TARGET file - the first object that show up. Below are the functions to do so.

# %%
def find_dup_and_identify_index(target_lst):
    
    # Dictionary to track the indices of duplicates
    index_dict = {}
    duplicates = []
    
    # Identify indices of duplicated items
    for idx, item in enumerate(target_lst):
        if item in index_dict:
            duplicates.append(index_dict[item])  # Record the first occurrence index
            index_dict[item] = idx  # Update to the latest index
        else:
            index_dict[item] = idx
    
    return duplicates

# %%
def drop_target_duplication(index_lst, idf, obj_type):
    
    #If the length of duplication index list is not zero, pop the curve objet, else do nothing
    if len(index_lst) > 0:
        
        #VERY IMPORTANT: Iterate backwards over the indices to avoid shifting issues
        for idx in reversed(index_lst):
            idf.idfobjects[obj_type].pop(idx)

# %%
#Identify HVAC related CURVE object types exist in both files. 
#AVAILABILITY needs to be capitalized as object types are capitalized in idf files.
curve_target=[s for s in target_WH_list if "CURVE" in s]
curve_source=[s for s in source_WH_list if "CURVE" in s]

#AirLoopHVAC can be different object types in target and source files. Print out the object types in sequence of target and source.
print(curve_target, curve_source)
# Out:
# ['CURVE:QUADRATIC', 'CURVE:CUBIC', 'CURVE:EXPONENT', 'CURVE:BIQUADRATIC'] ['CURVE:QUADRATIC', 'CURVE:CUBIC', 'CURVE:BIQUADRATIC']

# %% [markdown]
# This means that no new type of curve is involved in the source file. This can make the curve replacement and addition process much easier. We can handle all types of Curve all together.

# %%
if curve_target == curve_source:
    
    for curve_type in curve_source:
        lst_curve = targetidf.idfobjects[curve_type]
        new_curves = sourceidf.idfobjects[curve_type][:] #We will migrate all curves from the source file
        
        for i in range(len(new_curves)):
            targetidf.copyidfobject(new_curves[i])
        
        #Now we start the duplication check
        lst_curve_name=[]
        for i in range(len(lst_curve)):
            lst_curve_name.append(lst_curve[i].Name)
        dup_curve_index=find_dup_and_identify_index(lst_curve_name)
        
        #If any duplicated curve names exist, drop the first one that existed in the original target file
        drop_target_duplication(dup_curve_index, targetidf, curve_type)

# %% [markdown]
# In case the target and source files have different Curve types, we will simply repeat the above process but adding new curve types from the source file to the target file.

# %%
if curve_target != curve_source:
    
    for i in range(len(curve_source)):
        
        #When there are new curve types in the source file
        if curve_source[i] not in curve_target:
            lst_curve = targetidf.idfobjects[curve_source[i]] #Supposed to be an empty list
            new_curves = sourceidf.idfobjects[curve_source[i]][:]
            for a in range(len(new_curves)):
                targetidf.copyidfobject(new_curves[a]) #No need to check duplications
        
        #Then repeat the same process for those same existing curve types
        elif curve_source[i] in curve_target:
            lst_curve = targetidf.idfobjects[curve_source[i]] #Supposed to be a non-empty list
            new_curves = sourceidf.idfobjects[curve_source[i]][:]
            for b in range(len(new_curves)):
                targetidf.copyidfobject(new_curves[b]) #Need to check duplications
            #Check for duplications
            lst_curve_name=[]
            for c in range(len(lst_curve)):
                lst_curve_name.append(lst_curve[c].Name)
            dup_curve_index=find_dup_and_identify_index(lst_curve_name)
            #If any duplicated curve names exist, drop the first one that existed in the original target file
            drop_target_duplication(dup_curve_index, targetidf, curve_source[i])

# %% [markdown]
# # Schedule

# %% [markdown]
# The remaining item is to check if any shedules should be added from source to target. We first review all used object types with all associated fieldnames in the target file.

# %%
#Create two empty lists, one for object type, one for the associated fieldnames
obj_types=[]
obj_type_fieldnames=[]

#Pull out all used object type and associated fieldnames
for obj_type in source_WH_list:
    if len(targetidf.idfobjects[obj_type]) > 0:
        obj=targetidf.idfobjects[obj_type][0]
        obj_types.append(obj_type)
        fieldnames=obj.fieldnames
        obj_type_fieldnames.append(fieldnames)

#Organize the object types and fieldnames into a dictionary
obj_fieldnames_dict=dict(zip(obj_types, obj_type_fieldnames))
obj_fieldnames_dict
# Out:
# {'Sizing:ZONE': ['key',
#   'Zone_or_ZoneList_Name',
#   'Zone_Cooling_Design_Supply_Air_Temperature_Input_Method',
#   'Zone_Cooling_Design_Supply_Air_Temperature',
#   'Zone_Cooling_Design_Supply_Air_Temperature_Difference',
#   'Zone_Heating_Design_Supply_Air_Temperature_Input_Method',
#   'Zone_Heating_Design_Supply_Air_Temperature',
#   'Zone_Heating_Design_Supply_Air_Temperature_Difference',
#   'Zone_Cooling_Design_Supply_Air_Humidity_Ratio',
#   'Zone_Heating_Design_Supply_Air_Humidity_Ratio',
#   'Design_Specification_Outdoor_Air_Object_Name',
#   'Zone_Heating_Sizing_Factor',
#   'Zone_Cooling_Sizing_Factor',
#   'Cooling_Design_Air_Flow_Method',
#   'Cooling_Design_Air_Flow_Rate',
#   'Cooling_Minimum_Air_Flow_per_Zone_Floor_Area',
#   'Cooling_Minimum_Air_Flow',
#   'Cooling_Minimum_Air_Flow_Fraction',
#   'Heating_Design_Air_Flow_Method',
#   'Heating_Design_Air_Flow_Rate',
#   'Heating_Maximum_Air_Flow_per_Zone_Floor_Area',
#   'Heating_Maximum_Air_Flow',
#   'Heating_Maximum_Air_Flow_Fraction',
#   'Design_Specification_Zone_Air_Distribution_Object_Name',
#   'Account_for_Dedicated_Outdoor_Air_System',
#   'Dedicated_Outdoor_Air_System_Control_Strategy',
#   'Dedicated_Outdoor_Air_Low_Setpoint_Temperature_for_Design',
#   'Dedicated_Outdoor_Air_High_Setpoint_Temperature_for_Design',
#   'Zone_Load_Sizing_Method',
#   'Zone_Latent_Cooling_Design_Supply_Air_Humidity_Ratio_Input_Method',
#   'Zone_Dehumidification_Design_Supply_Air_Humidity_Ratio',
#   'Zone_Cooling_Design_Supply_Air_Humidity_Ratio_Difference',
#   'Zone_Latent_Heating_Design_Supply_Air_Humidity_Ratio_Input_Method',
#   'Zone_Humidification_Design_Supply_Air_Humidity_Ratio',
#   'Zone_Humidification_Design_Supply_Air_Humidity_Ratio_Difference',
#   'Zone_Humidistat_Dehumidification_Set_Point_Schedule_Name',
#   'Zone_Humidistat_Humidification_Set_Point_Schedule_Name'],
#  'SIZING:PLANT': ['key',
#   'Plant_or_Condenser_Loop_Name',
#   'Loop_Type',
#   'Design_Loop_Exit_Temperature',
#   'Loop_Design_Temperature_Difference',
#   'Sizing_Option',
#   'Zone_Timesteps_in_Averaging_Window',
#   'Coincident_Sizing_Factor_Mode'],
#  'COIL:WATERHEATING:AIRTOWATERHEATPUMP:WRAPPED': ['key',
#   'Name',
#   'Rated_Heating_Capacity',
#   'Rated_COP',
#   'Rated_Sensible_Heat_Ratio',
#   'Rated_Evaporator_Inlet_Air_DryBulb_Temperature',
#   'Rated_Evaporator_Inlet_Air_WetBulb_Temperature',
#   'Rated_Condenser_Water_Temperature',
#   'Rated_Evaporator_Air_Flow_Rate',
#   'Evaporator_Fan_Power_Included_in_Rated_COP',
#   'Evaporator_Air_Inlet_Node_Name',
#   'Evaporator_Air_Outlet_Node_Name',
#   'Crankcase_Heater_Capacity',
#   'Maximum_Ambient_Temperature_for_Crankcase_Heater_Operation',
#   'Evaporator_Air_Temperature_Type_for_Curve_Objects',
#   'Heating_Capacity_Function_of_Temperature_Curve_Name',
#   'Heating_Capacity_Function_of_Air_Flow_Fraction_Curve_Name',
#   'Heating_COP_Function_of_Temperature_Curve_Name',
#   'Heating_COP_Function_of_Air_Flow_Fraction_Curve_Name',
#   'Part_Load_Fraction_Correlation_Curve_Name'],
#  'FAN:SYSTEMMODEL': ['key',
#   'Name',
#   'Availability_Schedule_Name',
#   'Air_Inlet_Node_Name',
#   'Air_Outlet_Node_Name',
#   'Design_Maximum_Air_Flow_Rate',
#   'Speed_Control_Method',
#   'Electric_Power_Minimum_Flow_Rate_Fraction',
#   'Design_Pressure_Rise',
#   'Motor_Efficiency',
#   'Motor_In_Air_Stream_Fraction',
#   'Design_Electric_Power_Consumption',
#   'Design_Power_Sizing_Method',
#   'Electric_Power_Per_Unit_Flow_Rate',
#   'Electric_Power_Per_Unit_Flow_Rate_Per_Unit_Pressure',
#   'Fan_Total_Efficiency',
#   'Electric_Power_Function_of_Flow_Fraction_Curve_Name',
#   'Night_Ventilation_Mode_Pressure_Rise',
#   'Night_Ventilation_Mode_Flow_Fraction',
#   'Motor_Loss_Zone_Name',
#   'Motor_Loss_Radiative_Fraction',
#   'EndUse_Subcategory',
#   'Number_of_Speeds',
#   'Speed_1_Flow_Fraction',
#   'Speed_1_Electric_Power_Fraction',
#   'Speed_2_Flow_Fraction',
#   'Speed_2_Electric_Power_Fraction',
#   'Speed_3_Flow_Fraction',
#   'Speed_3_Electric_Power_Fraction',
#   'Speed_n_Flow_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction',
#   'Speed_n_Electric_Power_Fraction'],
#  'PIPE:ADIABATIC': ['key', 'Name', 'Inlet_Node_Name', 'Outlet_Node_Name'],
#  'PUMP:CONSTANTSPEED': ['key',
#   'Name',
#   'Inlet_Node_Name',
#   'Outlet_Node_Name',
#   'Design_Flow_Rate',
#   'Design_Pump_Head',
#   'Design_Power_Consumption',
#   'Motor_Efficiency',
#   'Fraction_of_Motor_Inefficiencies_to_Fluid_Stream',
#   'Pump_Control_Type',
#   'Pump_Flow_Rate_Schedule_Name',
#   'Pump_Curve_Name',
#   'Impeller_Diameter',
#   'Rotational_Speed',
#   'Zone_Name',
#   'Skin_Loss_Radiative_Fraction',
#   'Design_Power_Sizing_Method',
#   'Design_Electric_Power_per_Unit_Flow_Rate',
#   'Design_Shaft_Power_per_Unit_Flow_Rate_per_Unit_Head',
#   'EndUse_Subcategory'],
#  'WATERHEATER:STRATIFIED': ['key',
#   'Name',
#   'EndUse_Subcategory',
#   'Tank_Volume',
#   'Tank_Height',
#   'Tank_Shape',
#   'Tank_Perimeter',
#   'Maximum_Temperature_Limit',
#   'Heater_Priority_Control',
#   'Heater_1_Setpoint_Temperature_Schedule_Name',
#   'Heater_1_Deadband_Temperature_Difference',
#   'Heater_1_Capacity',
#   'Heater_1_Height',
#   'Heater_2_Setpoint_Temperature_Schedule_Name',
#   'Heater_2_Deadband_Temperature_Difference',
#   'Heater_2_Capacity',
#   'Heater_2_Height',
#   'Heater_Fuel_Type',
#   'Heater_Thermal_Efficiency',
#   'Off_Cycle_Parasitic_Fuel_Consumption_Rate',
#   'Off_Cycle_Parasitic_Fuel_Type',
#   'Off_Cycle_Parasitic_Heat_Fraction_to_Tank',
#   'Off_Cycle_Parasitic_Height',
#   'On_Cycle_Parasitic_Fuel_Consumption_Rate',
#   'On_Cycle_Parasitic_Fuel_Type',
#   'On_Cycle_Parasitic_Heat_Fraction_to_Tank',
#   'On_Cycle_Parasitic_Height',
#   'Ambient_Temperature_Indicator',
#   'Ambient_Temperature_Schedule_Name',
#   'Ambient_Temperature_Zone_Name',
#   'Ambient_Temperature_Outdoor_Air_Node_Name',
#   'Uniform_Skin_Loss_Coefficient_per_Unit_Area_to_Ambient_Temperature',
#   'Skin_Loss_Fraction_to_Zone',
#   'Off_Cycle_Flue_Loss_Coefficient_to_Ambient_Temperature',
#   'Off_Cycle_Flue_Loss_Fraction_to_Zone',
#   'Peak_Use_Flow_Rate',
#   'Use_Flow_Rate_Fraction_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name',
#   'Use_Side_Inlet_Node_Name',
#   'Use_Side_Outlet_Node_Name',
#   'Use_Side_Effectiveness',
#   'Use_Side_Inlet_Height',
#   'Use_Side_Outlet_Height',
#   'Source_Side_Inlet_Node_Name',
#   'Source_Side_Outlet_Node_Name',
#   'Source_Side_Effectiveness',
#   'Source_Side_Inlet_Height',
#   'Source_Side_Outlet_Height',
#   'Inlet_Mode',
#   'Use_Side_Design_Flow_Rate',
#   'Source_Side_Design_Flow_Rate',
#   'Indirect_Water_Heating_Recovery_Time',
#   'Number_of_Nodes',
#   'Additional_Destratification_Conductivity',
#   'Node_1_Additional_Loss_Coefficient',
#   'Node_2_Additional_Loss_Coefficient',
#   'Node_3_Additional_Loss_Coefficient',
#   'Node_4_Additional_Loss_Coefficient',
#   'Node_5_Additional_Loss_Coefficient',
#   'Node_6_Additional_Loss_Coefficient',
#   'Node_7_Additional_Loss_Coefficient',
#   'Node_8_Additional_Loss_Coefficient',
#   'Node_9_Additional_Loss_Coefficient',
#   'Node_10_Additional_Loss_Coefficient',
#   'Node_11_Additional_Loss_Coefficient',
#   'Node_12_Additional_Loss_Coefficient',
#   'Source_Side_Flow_Control_Mode',
#   'Indirect_Alternate_Setpoint_Temperature_Schedule_Name'],
#  'WATERHEATER:SIZING': ['key',
#   'WaterHeater_Name',
#   'Design_Mode',
#   'Time_Storage_Can_Meet_Peak_Draw',
#   'Time_for_Tank_Recovery',
#   'Nominal_Tank_Volume_for_Autosizing_Plant_Connections',
#   'Number_of_Bedrooms',
#   'Number_of_Bathrooms',
#   'Storage_Capacity_per_Person',
#   'Recovery_Capacity_per_Person',
#   'Storage_Capacity_per_Floor_Area',
#   'Recovery_Capacity_per_Floor_Area',
#   'Number_of_Units',
#   'Storage_Capacity_per_Unit',
#   'Recovery_Capacity_PerUnit',
#   'Storage_Capacity_per_Collector_Area',
#   'Height_Aspect_Ratio'],
#  'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER': ['key',
#   'Name',
#   'Availability_Schedule_Name',
#   'Compressor_Setpoint_Temperature_Schedule_Name',
#   'Dead_Band_Temperature_Difference',
#   'Condenser_Bottom_Location',
#   'Condenser_Top_Location',
#   'Evaporator_Air_Flow_Rate',
#   'Inlet_Air_Configuration',
#   'Air_Inlet_Node_Name',
#   'Air_Outlet_Node_Name',
#   'Outdoor_Air_Node_Name',
#   'Exhaust_Air_Node_Name',
#   'Inlet_Air_Temperature_Schedule_Name',
#   'Inlet_Air_Humidity_Schedule_Name',
#   'Inlet_Air_Zone_Name',
#   'Tank_Object_Type',
#   'Tank_Name',
#   'Tank_Use_Side_Inlet_Node_Name',
#   'Tank_Use_Side_Outlet_Node_Name',
#   'DX_Coil_Object_Type',
#   'DX_Coil_Name',
#   'Minimum_Inlet_Air_Temperature_for_Compressor_Operation',
#   'Maximum_Inlet_Air_Temperature_for_Compressor_Operation',
#   'Compressor_Location',
#   'Compressor_Ambient_Temperature_Schedule_Name',
#   'Fan_Object_Type',
#   'Fan_Name',
#   'Fan_Placement',
#   'On_Cycle_Parasitic_Electric_Load',
#   'Off_Cycle_Parasitic_Electric_Load',
#   'Parasitic_Heat_Rejection_Location',
#   'Inlet_Air_Mixer_Node_Name',
#   'Outlet_Air_Splitter_Node_Name',
#   'Inlet_Air_Mixer_Schedule_Name',
#   'Tank_Element_Control_Logic',
#   'Control_Sensor_1_Height_In_Stratified_Tank',
#   'Control_Sensor_1_Weight',
#   'Control_Sensor_2_Height_In_Stratified_Tank'],
#  'BRANCH': ['key',
#   'Name',
#   'Pressure_Drop_Curve_Name',
#   'Component_1_Object_Type',
#   'Component_1_Name',
#   'Component_1_Inlet_Node_Name',
#   'Component_1_Outlet_Node_Name',
#   'Component_2_Object_Type',
#   'Component_2_Name',
#   'Component_2_Inlet_Node_Name',
#   'Component_2_Outlet_Node_Name',
#   'Component_3_Object_Type',
#   'Component_3_Name',
#   'Component_3_Inlet_Node_Name',
#   'Component_3_Outlet_Node_Name',
#   'Component_4_Object_Type',
#   'Component_4_Name',
#   'Component_4_Inlet_Node_Name',
#   'Component_4_Outlet_Node_Name',
#   'Component_5_Object_Type',
#   'Component_5_Name',
#   'Component_5_Inlet_Node_Name',
#   'Component_5_Outlet_Node_Name',
#   'Component_6_Object_Type',
#   'Component_6_Name',
#   'Component_6_Inlet_Node_Name',
#   'Component_6_Outlet_Node_Name',
#   'Component_7_Object_Type',
#   'Component_7_Name',
#   'Component_7_Inlet_Node_Name',
#   'Component_7_Outlet_Node_Name',
#   'Component_8_Object_Type',
#   'Component_8_Name',
#   'Component_8_Inlet_Node_Name',
#   'Component_8_Outlet_Node_Name',
#   'Component_9_Object_Type',
#   'Component_9_Name',
#   'Component_9_Inlet_Node_Name',
#   'Component_9_Outlet_Node_Name',
#   'Component_10_Object_Type',
#   'Component_10_Name',
#   'Component_10_Inlet_Node_Name',
#   'Component_10_Outlet_Node_Name',
#   'Component_11_Object_Type',
#   'Component_11_Name',
#   'Component_11_Inlet_Node_Name',
#   'Component_11_Outlet_Node_Name'],
#  'BRANCHLIST': ['key',
#   'Name',
#   'Branch_1_Name',
#   'Branch_2_Name',
#   'Branch_3_Name',
#   'Branch_4_Name',
#   'Branch_5_Name',
#   'Branch_6_Name',
#   'Branch_7_Name',
#   'Branch_8_Name',
#   'Branch_9_Name',
#   'Branch_10_Name',
#   'Branch_11_Name',
#   'Branch_12_Name',
#   'Branch_13_Name',
#   'Branch_14_Name',
#   'Branch_15_Name',
#   'Branch_16_Name',
#   'Branch_17_Name',
#   'Branch_18_Name',
#   'Branch_19_Name',
#   'Branch_20_Name',
#   'Branch_21_Name',
#   'Branch_22_Name',
#   'Branch_23_Name',
#   'Branch_24_Name',
#   'Branch_25_Name',
#   'Branch_26_Name',
#   'Branch_27_Name',
#   'Branch_28_Name',
#   'Branch_29_Name',
#   'Branch_30_Name',
#   'Branch_31_Name',
#   'Branch_32_Name',
#   'Branch_33_Name',
#   'Branch_34_Name',
#   'Branch_35_Name',
#   'Branch_36_Name',
#   'Branch_37_Name',
#   'Branch_38_Name',
#   'Branch_39_Name',
#   'Branch_40_Name',
#   'Branch_41_Name',
#   'Branch_42_Name',
#   'Branch_43_Name',
#   'Branch_44_Name',
#   'Branch_45_Name',
#   'Branch_46_Name',
#   'Branch_47_Name',
#   'Branch_48_Name',
#   'Branch_49_Name',
#   'Branch_50_Name',
#   'Branch_51_Name',
#   'Branch_52_Name',
#   'Branch_53_Name',
#   'Branch_54_Name',
#   'Branch_55_Name',
#   'Branch_56_Name',
#   'Branch_57_Name',
#   'Branch_58_Name',
#   'Branch_59_Name',
#   'Branch_60_Name',
#   'Branch_61_Name',
#   'Branch_62_Name',
#   'Branch_63_Name',
#   'Branch_64_Name',
#   'Branch_65_Name',
#   'Branch_66_Name',
#   'Branch_67_Name',
#   'Branch_68_Name',
#   'Branch_69_Name',
#   'Branch_70_Name',
#   'Branch_71_Name',
#   'Branch_72_Name',
#   'Branch_73_Name',
#   'Branch_74_Name',
#   'Branch_75_Name',
#   'Branch_76_Name',
#   'Branch_77_Name',
#   'Branch_78_Name',
#   'Branch_79_Name',
#   'Branch_80_Name',
#   'Branch_81_Name',
#   'Branch_82_Name',
#   'Branch_83_Name',
#   'Branch_84_Name',
#   'Branch_85_Name',
#   'Branch_86_Name',
#   'Branch_87_Name',
#   'Branch_88_Name',
#   'Branch_89_Name',
#   'Branch_90_Name',
#   'Branch_91_Name',
#   'Branch_92_Name',
#   'Branch_93_Name',
#   'Branch_94_Name',
#   'Branch_95_Name',
#   'Branch_96_Name',
#   'Branch_97_Name',
#   'Branch_98_Name',
#   'Branch_99_Name',
#   'Branch_100_Name',
#   'Branch_101_Name',
#   'Branch_102_Name',
#   'Branch_103_Name',
#   'Branch_104_Name',
#   'Branch_105_Name',
#   'Branch_106_Name',
#   'Branch_107_Name',
#   'Branch_108_Name',
#   'Branch_109_Name',
#   'Branch_110_Name',
#   'Branch_111_Name',
#   'Branch_112_Name',
#   'Branch_113_Name',
#   'Branch_114_Name',
#   'Branch_115_Name',
#   'Branch_116_Name',
#   'Branch_117_Name',
#   'Branch_118_Name',
#   'Branch_119_Name',
#   'Branch_120_Name',
#   'Branch_121_Name',
#   'Branch_122_Name',
#   'Branch_123_Name',
#   'Branch_124_Name',
#   'Branch_125_Name',
#   'Branch_126_Name',
#   'Branch_127_Name',
#   'Branch_128_Name',
#   'Branch_129_Name',
#   'Branch_130_Name',
#   'Branch_131_Name',
#   'Branch_132_Name',
#   'Branch_133_Name',
#   'Branch_134_Name',
#   'Branch_135_Name',
#   'Branch_136_Name',
#   'Branch_137_Name',
#   'Branch_138_Name',
#   'Branch_139_Name',
#   'Branch_140_Name',
#   'Branch_141_Name',
#   'Branch_142_Name',
#   'Branch_143_Name',
#   'Branch_144_Name',
#   'Branch_145_Name',
#   'Branch_146_Name',
#   'Branch_147_Name',
#   'Branch_148_Name',
#   'Branch_149_Name',
#   'Branch_150_Name',
#   'Branch_151_Name',
#   'Branch_152_Name',
#   'Branch_153_Name',
#   'Branch_154_Name',
#   'Branch_155_Name',
#   'Branch_156_Name',
#   'Branch_157_Name',
#   'Branch_158_Name',
#   'Branch_159_Name',
#   'Branch_160_Name',
#   'Branch_161_Name',
#   'Branch_162_Name',
#   'Branch_163_Name',
#   'Branch_164_Name',
#   'Branch_165_Name',
#   'Branch_166_Name',
#   'Branch_167_Name',
#   'Branch_168_Name',
#   'Branch_169_Name',
#   'Branch_170_Name',
#   'Branch_171_Name',
#   'Branch_172_Name',
#   'Branch_173_Name',
#   'Branch_174_Name',
#   'Branch_175_Name',
#   'Branch_176_Name',
#   'Branch_177_Name',
#   'Branch_178_Name',
#   'Branch_179_Name',
#   'Branch_180_Name',
#   'Branch_181_Name',
#   'Branch_182_Name',
#   'Branch_183_Name',
#   'Branch_184_Name',
#   'Branch_185_Name',
#   'Branch_186_Name',
#   'Branch_187_Name',
#   'Branch_188_Name',
#   'Branch_189_Name',
#   'Branch_190_Name',
#   'Branch_191_Name',
#   'Branch_192_Name',
#   'Branch_193_Name',
#   'Branch_194_Name',
#   'Branch_195_Name',
#   'Branch_196_Name',
#   'Branch_197_Name',
#   'Branch_198_Name',
#   'Branch_199_Name',
#   'Branch_200_Name',
#   'Branch_201_Name',
#   'Branch_202_Name',
#   'Branch_203_Name',
#   'Branch_204_Name',
#   'Branch_205_Name',
#   'Branch_206_Name',
#   'Branch_207_Name',
#   'Branch_208_Name',
#   'Branch_209_Name',
#   'Branch_210_Name',
#   'Branch_211_Name',
#   'Branch_212_Name',
#   'Branch_213_Name',
#   'Branch_214_Name',
#   'Branch_215_Name',
#   'Branch_216_Name',
#   'Branch_217_Name',
#   'Branch_218_Name',
#   'Branch_219_Name',
#   'Branch_220_Name',
#   'Branch_221_Name',
#   'Branch_222_Name',
#   'Branch_223_Name',
#   'Branch_224_Name',
#   'Branch_225_Name',
#   'Branch_226_Name',
#   'Branch_227_Name',
#   'Branch_228_Name',
#   'Branch_229_Name',
#   'Branch_230_Name',
#   'Branch_231_Name',
#   'Branch_232_Name',
#   'Branch_233_Name',
#   'Branch_234_Name',
#   'Branch_235_Name',
#   'Branch_236_Name',
#   'Branch_237_Name',
#   'Branch_238_Name',
#   'Branch_239_Name',
#   'Branch_240_Name',
#   'Branch_241_Name',
#   'Branch_242_Name',
#   'Branch_243_Name',
#   'Branch_244_Name',
#   'Branch_245_Name',
#   'Branch_246_Name',
#   'Branch_247_Name',
#   'Branch_248_Name',
#   'Branch_249_Name',
#   'Branch_250_Name',
#   'Branch_251_Name',
#   'Branch_252_Name',
#   'Branch_253_Name',
#   'Branch_254_Name',
#   'Branch_255_Name',
#   'Branch_256_Name',
#   'Branch_257_Name',
#   'Branch_258_Name',
#   'Branch_259_Name',
#   'Branch_260_Name',
#   'Branch_261_Name',
#   'Branch_262_Name',
#   'Branch_263_Name',
#   'Branch_264_Name',
#   'Branch_265_Name',
#   'Branch_266_Name',
#   'Branch_267_Name',
#   'Branch_268_Name',
#   'Branch_269_Name',
#   'Branch_270_Name',
#   'Branch_271_Name',
#   'Branch_272_Name',
#   'Branch_273_Name',
#   'Branch_274_Name',
#   'Branch_275_Name',
#   'Branch_276_Name',
#   'Branch_277_Name',
#   'Branch_278_Name',
#   'Branch_279_Name',
#   'Branch_280_Name',
#   'Branch_281_Name',
#   'Branch_282_Name',
#   'Branch_283_Name',
#   'Branch_284_Name',
#   'Branch_285_Name',
#   'Branch_286_Name',
#   'Branch_287_Name',
#   'Branch_288_Name',
#   'Branch_289_Name',
#   'Branch_290_Name',
#   'Branch_291_Name',
#   'Branch_292_Name',
#   'Branch_293_Name',
#   'Branch_294_Name',
#   'Branch_295_Name',
#   'Branch_296_Name',
#   'Branch_297_Name',
#   'Branch_298_Name',
#   'Branch_299_Name',
#   'Branch_300_Name',
#   'Branch_301_Name',
#   'Branch_302_Name',
#   'Branch_303_Name',
#   'Branch_304_Name',
#   'Branch_305_Name',
#   'Branch_306_Name',
#   'Branch_307_Name',
#   'Branch_308_Name',
#   'Branch_309_Name',
#   'Branch_310_Name',
#   'Branch_311_Name',
#   'Branch_312_Name',
#   'Branch_313_Name',
#   'Branch_314_Name',
#   'Branch_315_Name',
#   'Branch_316_Name',
#   'Branch_317_Name',
#   'Branch_318_Name',
#   'Branch_319_Name',
#   'Branch_320_Name',
#   'Branch_321_Name',
#   'Branch_322_Name',
#   'Branch_323_Name',
#   'Branch_324_Name',
#   'Branch_325_Name',
#   'Branch_326_Name',
#   'Branch_327_Name',
#   'Branch_328_Name',
#   'Branch_329_Name',
#   'Branch_330_Name',
#   'Branch_331_Name',
#   'Branch_332_Name',
#   'Branch_333_Name',
#   'Branch_334_Name',
#   'Branch_335_Name',
#   'Branch_336_Name',
#   'Branch_337_Name',
#   'Branch_338_Name',
#   'Branch_339_Name',
#   'Branch_340_Name',
#   'Branch_341_Name',
#   'Branch_342_Name',
#   'Branch_343_Name',
#   'Branch_344_Name',
#   'Branch_345_Name',
#   'Branch_346_Name',
#   'Branch_347_Name',
#   'Branch_348_Name',
#   'Branch_349_Name',
#   'Branch_350_Name',
#   'Branch_351_Name',
#   'Branch_352_Name',
#   'Branch_353_Name',
#   'Branch_354_Name',
#   'Branch_355_Name',
#   'Branch_356_Name',
#   'Branch_357_Name',
#   'Branch_358_Name',
#   'Branch_359_Name',
#   'Branch_360_Name',
#   'Branch_361_Name',
#   'Branch_362_Name',
#   'Branch_363_Name',
#   'Branch_364_Name',
#   'Branch_365_Name',
#   'Branch_366_Name',
#   'Branch_367_Name',
#   'Branch_368_Name',
#   'Branch_369_Name',
#   'Branch_370_Name',
#   'Branch_371_Name',
#   'Branch_372_Name',
#   'Branch_373_Name',
#   'Branch_374_Name',
#   'Branch_375_Name',
#   'Branch_376_Name',
#   'Branch_377_Name',
#   'Branch_378_Name',
#   'Branch_379_Name',
#   'Branch_380_Name',
#   'Branch_381_Name',
#   'Branch_382_Name',
#   'Branch_383_Name',
#   'Branch_384_Name',
#   'Branch_385_Name',
#   'Branch_386_Name',
#   'Branch_387_Name',
#   'Branch_388_Name',
#   'Branch_389_Name',
#   'Branch_390_Name',
#   'Branch_391_Name',
#   'Branch_392_Name',
#   'Branch_393_Name',
#   'Branch_394_Name',
#   'Branch_395_Name',
#   'Branch_396_Name',
#   'Branch_397_Name',
#   'Branch_398_Name',
#   'Branch_399_Name',
#   'Branch_400_Name',
#   'Branch_401_Name',
#   'Branch_402_Name',
#   'Branch_403_Name',
#   'Branch_404_Name',
#   'Branch_405_Name',
#   'Branch_406_Name',
#   'Branch_407_Name',
#   'Branch_408_Name',
#   'Branch_409_Name',
#   'Branch_410_Name',
#   'Branch_411_Name',
#   'Branch_412_Name',
#   'Branch_413_Name',
#   'Branch_414_Name',
#   'Branch_415_Name',
#   'Branch_416_Name',
#   'Branch_417_Name',
#   'Branch_418_Name',
#   'Branch_419_Name',
#   'Branch_420_Name',
#   'Branch_421_Name',
#   'Branch_422_Name',
#   'Branch_423_Name',
#   'Branch_424_Name',
#   'Branch_425_Name',
#   'Branch_426_Name',
#   'Branch_427_Name',
#   'Branch_428_Name',
#   'Branch_429_Name',
#   'Branch_430_Name',
#   'Branch_431_Name',
#   'Branch_432_Name',
#   'Branch_433_Name',
#   'Branch_434_Name',
#   'Branch_435_Name',
#   'Branch_436_Name',
#   'Branch_437_Name',
#   'Branch_438_Name',
#   'Branch_439_Name',
#   'Branch_440_Name',
#   'Branch_441_Name',
#   'Branch_442_Name',
#   'Branch_443_Name',
#   'Branch_444_Name',
#   'Branch_445_Name',
#   'Branch_446_Name',
#   'Branch_447_Name',
#   'Branch_448_Name',
#   'Branch_449_Name',
#   'Branch_450_Name',
#   'Branch_451_Name',
#   'Branch_452_Name',
#   'Branch_453_Name',
#   'Branch_454_Name',
#   'Branch_455_Name',
#   'Branch_456_Name',
#   'Branch_457_Name',
#   'Branch_458_Name',
#   'Branch_459_Name',
#   'Branch_460_Name',
#   'Branch_461_Name',
#   'Branch_462_Name',
#   'Branch_463_Name',
#   'Branch_464_Name',
#   'Branch_465_Name',
#   'Branch_466_Name',
#   'Branch_467_Name',
#   'Branch_468_Name',
#   'Branch_469_Name',
#   'Branch_470_Name',
#   'Branch_471_Name',
#   'Branch_472_Name',
#   'Branch_473_Name',
#   'Branch_474_Name',
#   'Branch_475_Name',
#   'Branch_476_Name',
#   'Branch_477_Name',
#   'Branch_478_Name',
#   'Branch_479_Name',
#   'Branch_480_Name',
#   'Branch_481_Name',
#   'Branch_482_Name',
#   'Branch_483_Name',
#   'Branch_484_Name',
#   'Branch_485_Name',
#   'Branch_486_Name',
#   'Branch_487_Name',
#   'Branch_488_Name',
#   'Branch_489_Name',
#   'Branch_490_Name',
#   'Branch_491_Name',
#   'Branch_492_Name',
#   'Branch_493_Name',
#   'Branch_494_Name',
#   'Branch_495_Name',
#   'Branch_496_Name',
#   'Branch_497_Name',
#   'Branch_498_Name',
#   'Branch_499_Name',
#   'Branch_500_Name'],
#  'CONNECTOR:SPLITTER': ['key',
#   'Name',
#   'Inlet_Branch_Name',
#   'Outlet_Branch_1_Name',
#   'Outlet_Branch_2_Name',
#   'Outlet_Branch_3_Name',
#   'Outlet_Branch_4_Name',
#   'Outlet_Branch_5_Name',
#   'Outlet_Branch_6_Name',
#   'Outlet_Branch_7_Name',
#   'Outlet_Branch_8_Name',
#   'Outlet_Branch_9_Name',
#   'Outlet_Branch_10_Name',
#   'Outlet_Branch_11_Name',
#   'Outlet_Branch_12_Name',
#   'Outlet_Branch_13_Name',
#   'Outlet_Branch_14_Name',
#   'Outlet_Branch_15_Name',
#   'Outlet_Branch_16_Name',
#   'Outlet_Branch_17_Name',
#   'Outlet_Branch_18_Name',
#   'Outlet_Branch_19_Name',
#   'Outlet_Branch_20_Name',
#   'Outlet_Branch_21_Name',
#   'Outlet_Branch_22_Name',
#   'Outlet_Branch_23_Name',
#   'Outlet_Branch_24_Name',
#   'Outlet_Branch_25_Name',
#   'Outlet_Branch_26_Name',
#   'Outlet_Branch_27_Name',
#   'Outlet_Branch_28_Name',
#   'Outlet_Branch_29_Name',
#   'Outlet_Branch_30_Name',
#   'Outlet_Branch_31_Name',
#   'Outlet_Branch_32_Name',
#   'Outlet_Branch_33_Name',
#   'Outlet_Branch_34_Name',
#   'Outlet_Branch_35_Name',
#   'Outlet_Branch_36_Name',
#   'Outlet_Branch_37_Name',
#   'Outlet_Branch_38_Name',
#   'Outlet_Branch_39_Name',
#   'Outlet_Branch_40_Name',
#   'Outlet_Branch_41_Name',
#   'Outlet_Branch_42_Name',
#   'Outlet_Branch_43_Name',
#   'Outlet_Branch_44_Name',
#   'Outlet_Branch_45_Name',
#   'Outlet_Branch_46_Name',
#   'Outlet_Branch_47_Name',
#   'Outlet_Branch_48_Name',
#   'Outlet_Branch_49_Name',
#   'Outlet_Branch_50_Name',
#   'Outlet_Branch_51_Name',
#   'Outlet_Branch_52_Name',
#   'Outlet_Branch_53_Name',
#   'Outlet_Branch_54_Name',
#   'Outlet_Branch_55_Name',
#   'Outlet_Branch_56_Name',
#   'Outlet_Branch_57_Name',
#   'Outlet_Branch_58_Name',
#   'Outlet_Branch_59_Name',
#   'Outlet_Branch_60_Name',
#   'Outlet_Branch_61_Name',
#   'Outlet_Branch_62_Name',
#   'Outlet_Branch_63_Name',
#   'Outlet_Branch_64_Name',
#   'Outlet_Branch_65_Name',
#   'Outlet_Branch_66_Name',
#   'Outlet_Branch_67_Name',
#   'Outlet_Branch_68_Name',
#   'Outlet_Branch_69_Name',
#   'Outlet_Branch_70_Name',
#   'Outlet_Branch_71_Name',
#   'Outlet_Branch_72_Name',
#   'Outlet_Branch_73_Name',
#   'Outlet_Branch_74_Name',
#   'Outlet_Branch_75_Name',
#   'Outlet_Branch_76_Name',
#   'Outlet_Branch_77_Name',
#   'Outlet_Branch_78_Name',
#   'Outlet_Branch_79_Name',
#   'Outlet_Branch_80_Name',
#   'Outlet_Branch_81_Name',
#   'Outlet_Branch_82_Name',
#   'Outlet_Branch_83_Name',
#   'Outlet_Branch_84_Name',
#   'Outlet_Branch_85_Name',
#   'Outlet_Branch_86_Name',
#   'Outlet_Branch_87_Name',
#   'Outlet_Branch_88_Name',
#   'Outlet_Branch_89_Name',
#   'Outlet_Branch_90_Name',
#   'Outlet_Branch_91_Name',
#   'Outlet_Branch_92_Name',
#   'Outlet_Branch_93_Name',
#   'Outlet_Branch_94_Name',
#   'Outlet_Branch_95_Name',
#   'Outlet_Branch_96_Name',
#   'Outlet_Branch_97_Name',
#   'Outlet_Branch_98_Name',
#   'Outlet_Branch_99_Name',
#   'Outlet_Branch_100_Name',
#   'Outlet_Branch_101_Name',
#   'Outlet_Branch_102_Name',
#   'Outlet_Branch_103_Name',
#   'Outlet_Branch_104_Name',
#   'Outlet_Branch_105_Name',
#   'Outlet_Branch_106_Name',
#   'Outlet_Branch_107_Name',
#   'Outlet_Branch_108_Name',
#   'Outlet_Branch_109_Name',
#   'Outlet_Branch_110_Name',
#   'Outlet_Branch_111_Name',
#   'Outlet_Branch_112_Name',
#   'Outlet_Branch_113_Name',
#   'Outlet_Branch_114_Name',
#   'Outlet_Branch_115_Name',
#   'Outlet_Branch_116_Name',
#   'Outlet_Branch_117_Name',
#   'Outlet_Branch_118_Name',
#   'Outlet_Branch_119_Name',
#   'Outlet_Branch_120_Name',
#   'Outlet_Branch_121_Name',
#   'Outlet_Branch_122_Name',
#   'Outlet_Branch_123_Name',
#   'Outlet_Branch_124_Name',
#   'Outlet_Branch_125_Name',
#   'Outlet_Branch_126_Name',
#   'Outlet_Branch_127_Name',
#   'Outlet_Branch_128_Name',
#   'Outlet_Branch_129_Name',
#   'Outlet_Branch_130_Name',
#   'Outlet_Branch_131_Name',
#   'Outlet_Branch_132_Name',
#   'Outlet_Branch_133_Name',
#   'Outlet_Branch_134_Name',
#   'Outlet_Branch_135_Name',
#   'Outlet_Branch_136_Name',
#   'Outlet_Branch_137_Name',
#   'Outlet_Branch_138_Name',
#   'Outlet_Branch_139_Name',
#   'Outlet_Branch_140_Name',
#   'Outlet_Branch_141_Name',
#   'Outlet_Branch_142_Name',
#   'Outlet_Branch_143_Name',
#   'Outlet_Branch_144_Name',
#   'Outlet_Branch_145_Name',
#   'Outlet_Branch_146_Name',
#   'Outlet_Branch_147_Name',
#   'Outlet_Branch_148_Name',
#   'Outlet_Branch_149_Name',
#   'Outlet_Branch_150_Name',
#   'Outlet_Branch_151_Name',
#   'Outlet_Branch_152_Name',
#   'Outlet_Branch_153_Name',
#   'Outlet_Branch_154_Name',
#   'Outlet_Branch_155_Name',
#   'Outlet_Branch_156_Name',
#   'Outlet_Branch_157_Name',
#   'Outlet_Branch_158_Name',
#   'Outlet_Branch_159_Name',
#   'Outlet_Branch_160_Name',
#   'Outlet_Branch_161_Name',
#   'Outlet_Branch_162_Name',
#   'Outlet_Branch_163_Name',
#   'Outlet_Branch_164_Name',
#   'Outlet_Branch_165_Name',
#   'Outlet_Branch_166_Name',
#   'Outlet_Branch_167_Name',
#   'Outlet_Branch_168_Name',
#   'Outlet_Branch_169_Name',
#   'Outlet_Branch_170_Name',
#   'Outlet_Branch_171_Name',
#   'Outlet_Branch_172_Name',
#   'Outlet_Branch_173_Name',
#   'Outlet_Branch_174_Name',
#   'Outlet_Branch_175_Name',
#   'Outlet_Branch_176_Name',
#   'Outlet_Branch_177_Name',
#   'Outlet_Branch_178_Name',
#   'Outlet_Branch_179_Name',
#   'Outlet_Branch_180_Name',
#   'Outlet_Branch_181_Name',
#   'Outlet_Branch_182_Name',
#   'Outlet_Branch_183_Name',
#   'Outlet_Branch_184_Name',
#   'Outlet_Branch_185_Name',
#   'Outlet_Branch_186_Name',
#   'Outlet_Branch_187_Name',
#   'Outlet_Branch_188_Name',
#   'Outlet_Branch_189_Name',
#   'Outlet_Branch_190_Name',
#   'Outlet_Branch_191_Name',
#   'Outlet_Branch_192_Name',
#   'Outlet_Branch_193_Name',
#   'Outlet_Branch_194_Name',
#   'Outlet_Branch_195_Name',
#   'Outlet_Branch_196_Name',
#   'Outlet_Branch_197_Name',
#   'Outlet_Branch_198_Name',
#   'Outlet_Branch_199_Name',
#   'Outlet_Branch_200_Name',
#   'Outlet_Branch_201_Name',
#   'Outlet_Branch_202_Name',
#   'Outlet_Branch_203_Name',
#   'Outlet_Branch_204_Name',
#   'Outlet_Branch_205_Name',
#   'Outlet_Branch_206_Name',
#   'Outlet_Branch_207_Name',
#   'Outlet_Branch_208_Name',
#   'Outlet_Branch_209_Name',
#   'Outlet_Branch_210_Name',
#   'Outlet_Branch_211_Name',
#   'Outlet_Branch_212_Name',
#   'Outlet_Branch_213_Name',
#   'Outlet_Branch_214_Name',
#   'Outlet_Branch_215_Name',
#   'Outlet_Branch_216_Name',
#   'Outlet_Branch_217_Name',
#   'Outlet_Branch_218_Name',
#   'Outlet_Branch_219_Name',
#   'Outlet_Branch_220_Name',
#   'Outlet_Branch_221_Name',
#   'Outlet_Branch_222_Name',
#   'Outlet_Branch_223_Name',
#   'Outlet_Branch_224_Name',
#   'Outlet_Branch_225_Name',
#   'Outlet_Branch_226_Name',
#   'Outlet_Branch_227_Name',
#   'Outlet_Branch_228_Name',
#   'Outlet_Branch_229_Name',
#   'Outlet_Branch_230_Name',
#   'Outlet_Branch_231_Name',
#   'Outlet_Branch_232_Name',
#   'Outlet_Branch_233_Name',
#   'Outlet_Branch_234_Name',
#   'Outlet_Branch_235_Name',
#   'Outlet_Branch_236_Name',
#   'Outlet_Branch_237_Name',
#   'Outlet_Branch_238_Name',
#   'Outlet_Branch_239_Name',
#   'Outlet_Branch_240_Name',
#   'Outlet_Branch_241_Name',
#   'Outlet_Branch_242_Name',
#   'Outlet_Branch_243_Name',
#   'Outlet_Branch_244_Name',
#   'Outlet_Branch_245_Name',
#   'Outlet_Branch_246_Name',
#   'Outlet_Branch_247_Name',
#   'Outlet_Branch_248_Name',
#   'Outlet_Branch_249_Name',
#   'Outlet_Branch_250_Name',
#   'Outlet_Branch_251_Name',
#   'Outlet_Branch_252_Name',
#   'Outlet_Branch_253_Name',
#   'Outlet_Branch_254_Name',
#   'Outlet_Branch_255_Name',
#   'Outlet_Branch_256_Name',
#   'Outlet_Branch_257_Name',
#   'Outlet_Branch_258_Name',
#   'Outlet_Branch_259_Name',
#   'Outlet_Branch_260_Name',
#   'Outlet_Branch_261_Name',
#   'Outlet_Branch_262_Name',
#   'Outlet_Branch_263_Name',
#   'Outlet_Branch_264_Name',
#   'Outlet_Branch_265_Name',
#   'Outlet_Branch_266_Name',
#   'Outlet_Branch_267_Name',
#   'Outlet_Branch_268_Name',
#   'Outlet_Branch_269_Name',
#   'Outlet_Branch_270_Name',
#   'Outlet_Branch_271_Name',
#   'Outlet_Branch_272_Name',
#   'Outlet_Branch_273_Name',
#   'Outlet_Branch_274_Name',
#   'Outlet_Branch_275_Name',
#   'Outlet_Branch_276_Name',
#   'Outlet_Branch_277_Name',
#   'Outlet_Branch_278_Name',
#   'Outlet_Branch_279_Name',
#   'Outlet_Branch_280_Name',
#   'Outlet_Branch_281_Name',
#   'Outlet_Branch_282_Name',
#   'Outlet_Branch_283_Name',
#   'Outlet_Branch_284_Name',
#   'Outlet_Branch_285_Name',
#   'Outlet_Branch_286_Name',
#   'Outlet_Branch_287_Name',
#   'Outlet_Branch_288_Name',
#   'Outlet_Branch_289_Name',
#   'Outlet_Branch_290_Name',
#   'Outlet_Branch_291_Name',
#   'Outlet_Branch_292_Name',
#   'Outlet_Branch_293_Name',
#   'Outlet_Branch_294_Name',
#   'Outlet_Branch_295_Name',
#   'Outlet_Branch_296_Name',
#   'Outlet_Branch_297_Name',
#   'Outlet_Branch_298_Name',
#   'Outlet_Branch_299_Name',
#   'Outlet_Branch_300_Name',
#   'Outlet_Branch_301_Name',
#   'Outlet_Branch_302_Name',
#   'Outlet_Branch_303_Name',
#   'Outlet_Branch_304_Name',
#   'Outlet_Branch_305_Name',
#   'Outlet_Branch_306_Name',
#   'Outlet_Branch_307_Name',
#   'Outlet_Branch_308_Name',
#   'Outlet_Branch_309_Name',
#   'Outlet_Branch_310_Name',
#   'Outlet_Branch_311_Name',
#   'Outlet_Branch_312_Name',
#   'Outlet_Branch_313_Name',
#   'Outlet_Branch_314_Name',
#   'Outlet_Branch_315_Name',
#   'Outlet_Branch_316_Name',
#   'Outlet_Branch_317_Name',
#   'Outlet_Branch_318_Name',
#   'Outlet_Branch_319_Name',
#   'Outlet_Branch_320_Name',
#   'Outlet_Branch_321_Name',
#   'Outlet_Branch_322_Name',
#   'Outlet_Branch_323_Name',
#   'Outlet_Branch_324_Name',
#   'Outlet_Branch_325_Name',
#   'Outlet_Branch_326_Name',
#   'Outlet_Branch_327_Name',
#   'Outlet_Branch_328_Name',
#   'Outlet_Branch_329_Name',
#   'Outlet_Branch_330_Name',
#   'Outlet_Branch_331_Name',
#   'Outlet_Branch_332_Name',
#   'Outlet_Branch_333_Name',
#   'Outlet_Branch_334_Name',
#   'Outlet_Branch_335_Name',
#   'Outlet_Branch_336_Name',
#   'Outlet_Branch_337_Name',
#   'Outlet_Branch_338_Name',
#   'Outlet_Branch_339_Name',
#   'Outlet_Branch_340_Name',
#   'Outlet_Branch_341_Name',
#   'Outlet_Branch_342_Name',
#   'Outlet_Branch_343_Name',
#   'Outlet_Branch_344_Name',
#   'Outlet_Branch_345_Name',
#   'Outlet_Branch_346_Name',
#   'Outlet_Branch_347_Name',
#   'Outlet_Branch_348_Name',
#   'Outlet_Branch_349_Name',
#   'Outlet_Branch_350_Name',
#   'Outlet_Branch_351_Name',
#   'Outlet_Branch_352_Name',
#   'Outlet_Branch_353_Name',
#   'Outlet_Branch_354_Name',
#   'Outlet_Branch_355_Name',
#   'Outlet_Branch_356_Name',
#   'Outlet_Branch_357_Name',
#   'Outlet_Branch_358_Name',
#   'Outlet_Branch_359_Name',
#   'Outlet_Branch_360_Name',
#   'Outlet_Branch_361_Name',
#   'Outlet_Branch_362_Name',
#   'Outlet_Branch_363_Name',
#   'Outlet_Branch_364_Name',
#   'Outlet_Branch_365_Name',
#   'Outlet_Branch_366_Name',
#   'Outlet_Branch_367_Name',
#   'Outlet_Branch_368_Name',
#   'Outlet_Branch_369_Name',
#   'Outlet_Branch_370_Name',
#   'Outlet_Branch_371_Name',
#   'Outlet_Branch_372_Name',
#   'Outlet_Branch_373_Name',
#   'Outlet_Branch_374_Name',
#   'Outlet_Branch_375_Name',
#   'Outlet_Branch_376_Name',
#   'Outlet_Branch_377_Name',
#   'Outlet_Branch_378_Name',
#   'Outlet_Branch_379_Name',
#   'Outlet_Branch_380_Name',
#   'Outlet_Branch_381_Name',
#   'Outlet_Branch_382_Name',
#   'Outlet_Branch_383_Name',
#   'Outlet_Branch_384_Name',
#   'Outlet_Branch_385_Name',
#   'Outlet_Branch_386_Name',
#   'Outlet_Branch_387_Name',
#   'Outlet_Branch_388_Name',
#   'Outlet_Branch_389_Name',
#   'Outlet_Branch_390_Name',
#   'Outlet_Branch_391_Name',
#   'Outlet_Branch_392_Name',
#   'Outlet_Branch_393_Name',
#   'Outlet_Branch_394_Name',
#   'Outlet_Branch_395_Name',
#   'Outlet_Branch_396_Name',
#   'Outlet_Branch_397_Name',
#   'Outlet_Branch_398_Name',
#   'Outlet_Branch_399_Name',
#   'Outlet_Branch_400_Name',
#   'Outlet_Branch_401_Name',
#   'Outlet_Branch_402_Name',
#   'Outlet_Branch_403_Name',
#   'Outlet_Branch_404_Name',
#   'Outlet_Branch_405_Name',
#   'Outlet_Branch_406_Name',
#   'Outlet_Branch_407_Name',
#   'Outlet_Branch_408_Name',
#   'Outlet_Branch_409_Name',
#   'Outlet_Branch_410_Name',
#   'Outlet_Branch_411_Name',
#   'Outlet_Branch_412_Name',
#   'Outlet_Branch_413_Name',
#   'Outlet_Branch_414_Name',
#   'Outlet_Branch_415_Name',
#   'Outlet_Branch_416_Name',
#   'Outlet_Branch_417_Name',
#   'Outlet_Branch_418_Name',
#   'Outlet_Branch_419_Name',
#   'Outlet_Branch_420_Name',
#   'Outlet_Branch_421_Name',
#   'Outlet_Branch_422_Name',
#   'Outlet_Branch_423_Name',
#   'Outlet_Branch_424_Name',
#   'Outlet_Branch_425_Name',
#   'Outlet_Branch_426_Name',
#   'Outlet_Branch_427_Name',
#   'Outlet_Branch_428_Name',
#   'Outlet_Branch_429_Name',
#   'Outlet_Branch_430_Name',
#   'Outlet_Branch_431_Name',
#   'Outlet_Branch_432_Name',
#   'Outlet_Branch_433_Name',
#   'Outlet_Branch_434_Name',
#   'Outlet_Branch_435_Name',
#   'Outlet_Branch_436_Name',
#   'Outlet_Branch_437_Name',
#   'Outlet_Branch_438_Name',
#   'Outlet_Branch_439_Name',
#   'Outlet_Branch_440_Name',
#   'Outlet_Branch_441_Name',
#   'Outlet_Branch_442_Name',
#   'Outlet_Branch_443_Name',
#   'Outlet_Branch_444_Name',
#   'Outlet_Branch_445_Name',
#   'Outlet_Branch_446_Name',
#   'Outlet_Branch_447_Name',
#   'Outlet_Branch_448_Name',
#   'Outlet_Branch_449_Name',
#   'Outlet_Branch_450_Name',
#   'Outlet_Branch_451_Name',
#   'Outlet_Branch_452_Name',
#   'Outlet_Branch_453_Name',
#   'Outlet_Branch_454_Name',
#   'Outlet_Branch_455_Name',
#   'Outlet_Branch_456_Name',
#   'Outlet_Branch_457_Name',
#   'Outlet_Branch_458_Name',
#   'Outlet_Branch_459_Name',
#   'Outlet_Branch_460_Name',
#   'Outlet_Branch_461_Name',
#   'Outlet_Branch_462_Name',
#   'Outlet_Branch_463_Name',
#   'Outlet_Branch_464_Name',
#   'Outlet_Branch_465_Name',
#   'Outlet_Branch_466_Name',
#   'Outlet_Branch_467_Name',
#   'Outlet_Branch_468_Name',
#   'Outlet_Branch_469_Name',
#   'Outlet_Branch_470_Name',
#   'Outlet_Branch_471_Name',
#   'Outlet_Branch_472_Name',
#   'Outlet_Branch_473_Name',
#   'Outlet_Branch_474_Name',
#   'Outlet_Branch_475_Name',
#   'Outlet_Branch_476_Name',
#   'Outlet_Branch_477_Name',
#   'Outlet_Branch_478_Name',
#   'Outlet_Branch_479_Name',
#   'Outlet_Branch_480_Name',
#   'Outlet_Branch_481_Name',
#   'Outlet_Branch_482_Name',
#   'Outlet_Branch_483_Name',
#   'Outlet_Branch_484_Name',
#   'Outlet_Branch_485_Name',
#   'Outlet_Branch_486_Name',
#   'Outlet_Branch_487_Name',
#   'Outlet_Branch_488_Name',
#   'Outlet_Branch_489_Name',
#   'Outlet_Branch_490_Name',
#   'Outlet_Branch_491_Name',
#   'Outlet_Branch_492_Name',
#   'Outlet_Branch_493_Name',
#   'Outlet_Branch_494_Name',
#   'Outlet_Branch_495_Name',
#   'Outlet_Branch_496_Name',
#   'Outlet_Branch_497_Name',
#   'Outlet_Branch_498_Name',
#   'Outlet_Branch_499_Name',
#   'Outlet_Branch_500_Name'],
#  'CONNECTOR:MIXER': ['key',
#   'Name',
#   'Outlet_Branch_Name',
#   'Inlet_Branch_1_Name',
#   'Inlet_Branch_2_Name',
#   'Inlet_Branch_3_Name',
#   'Inlet_Branch_4_Name',
#   'Inlet_Branch_5_Name',
#   'Inlet_Branch_6_Name',
#   'Inlet_Branch_7_Name',
#   'Inlet_Branch_8_Name',
#   'Inlet_Branch_9_Name',
#   'Inlet_Branch_10_Name',
#   'Inlet_Branch_11_Name',
#   'Inlet_Branch_12_Name',
#   'Inlet_Branch_13_Name',
#   'Inlet_Branch_14_Name',
#   'Inlet_Branch_15_Name',
#   'Inlet_Branch_16_Name',
#   'Inlet_Branch_17_Name',
#   'Inlet_Branch_18_Name',
#   'Inlet_Branch_19_Name',
#   'Inlet_Branch_20_Name',
#   'Inlet_Branch_21_Name',
#   'Inlet_Branch_22_Name',
#   'Inlet_Branch_23_Name',
#   'Inlet_Branch_24_Name',
#   'Inlet_Branch_25_Name',
#   'Inlet_Branch_26_Name',
#   'Inlet_Branch_27_Name',
#   'Inlet_Branch_28_Name',
#   'Inlet_Branch_29_Name',
#   'Inlet_Branch_30_Name',
#   'Inlet_Branch_31_Name',
#   'Inlet_Branch_32_Name',
#   'Inlet_Branch_33_Name',
#   'Inlet_Branch_34_Name',
#   'Inlet_Branch_35_Name',
#   'Inlet_Branch_36_Name',
#   'Inlet_Branch_37_Name',
#   'Inlet_Branch_38_Name',
#   'Inlet_Branch_39_Name',
#   'Inlet_Branch_40_Name',
#   'Inlet_Branch_41_Name',
#   'Inlet_Branch_42_Name',
#   'Inlet_Branch_43_Name',
#   'Inlet_Branch_44_Name',
#   'Inlet_Branch_45_Name',
#   'Inlet_Branch_46_Name',
#   'Inlet_Branch_47_Name',
#   'Inlet_Branch_48_Name',
#   'Inlet_Branch_49_Name',
#   'Inlet_Branch_50_Name',
#   'Inlet_Branch_51_Name',
#   'Inlet_Branch_52_Name',
#   'Inlet_Branch_53_Name',
#   'Inlet_Branch_54_Name',
#   'Inlet_Branch_55_Name',
#   'Inlet_Branch_56_Name',
#   'Inlet_Branch_57_Name',
#   'Inlet_Branch_58_Name',
#   'Inlet_Branch_59_Name',
#   'Inlet_Branch_60_Name',
#   'Inlet_Branch_61_Name',
#   'Inlet_Branch_62_Name',
#   'Inlet_Branch_63_Name',
#   'Inlet_Branch_64_Name',
#   'Inlet_Branch_65_Name',
#   'Inlet_Branch_66_Name',
#   'Inlet_Branch_67_Name',
#   'Inlet_Branch_68_Name',
#   'Inlet_Branch_69_Name',
#   'Inlet_Branch_70_Name',
#   'Inlet_Branch_71_Name',
#   'Inlet_Branch_72_Name',
#   'Inlet_Branch_73_Name',
#   'Inlet_Branch_74_Name',
#   'Inlet_Branch_75_Name',
#   'Inlet_Branch_76_Name',
#   'Inlet_Branch_77_Name',
#   'Inlet_Branch_78_Name',
#   'Inlet_Branch_79_Name',
#   'Inlet_Branch_80_Name',
#   'Inlet_Branch_81_Name',
#   'Inlet_Branch_82_Name',
#   'Inlet_Branch_83_Name',
#   'Inlet_Branch_84_Name',
#   'Inlet_Branch_85_Name',
#   'Inlet_Branch_86_Name',
#   'Inlet_Branch_87_Name',
#   'Inlet_Branch_88_Name',
#   'Inlet_Branch_89_Name',
#   'Inlet_Branch_90_Name',
#   'Inlet_Branch_91_Name',
#   'Inlet_Branch_92_Name',
#   'Inlet_Branch_93_Name',
#   'Inlet_Branch_94_Name',
#   'Inlet_Branch_95_Name',
#   'Inlet_Branch_96_Name',
#   'Inlet_Branch_97_Name',
#   'Inlet_Branch_98_Name',
#   'Inlet_Branch_99_Name',
#   'Inlet_Branch_100_Name',
#   'Inlet_Branch_101_Name',
#   'Inlet_Branch_102_Name',
#   'Inlet_Branch_103_Name',
#   'Inlet_Branch_104_Name',
#   'Inlet_Branch_105_Name',
#   'Inlet_Branch_106_Name',
#   'Inlet_Branch_107_Name',
#   'Inlet_Branch_108_Name',
#   'Inlet_Branch_109_Name',
#   'Inlet_Branch_110_Name',
#   'Inlet_Branch_111_Name',
#   'Inlet_Branch_112_Name',
#   'Inlet_Branch_113_Name',
#   'Inlet_Branch_114_Name',
#   'Inlet_Branch_115_Name',
#   'Inlet_Branch_116_Name',
#   'Inlet_Branch_117_Name',
#   'Inlet_Branch_118_Name',
#   'Inlet_Branch_119_Name',
#   'Inlet_Branch_120_Name',
#   'Inlet_Branch_121_Name',
#   'Inlet_Branch_122_Name',
#   'Inlet_Branch_123_Name',
#   'Inlet_Branch_124_Name',
#   'Inlet_Branch_125_Name',
#   'Inlet_Branch_126_Name',
#   'Inlet_Branch_127_Name',
#   'Inlet_Branch_128_Name',
#   'Inlet_Branch_129_Name',
#   'Inlet_Branch_130_Name',
#   'Inlet_Branch_131_Name',
#   'Inlet_Branch_132_Name',
#   'Inlet_Branch_133_Name',
#   'Inlet_Branch_134_Name',
#   'Inlet_Branch_135_Name',
#   'Inlet_Branch_136_Name',
#   'Inlet_Branch_137_Name',
#   'Inlet_Branch_138_Name',
#   'Inlet_Branch_139_Name',
#   'Inlet_Branch_140_Name',
#   'Inlet_Branch_141_Name',
#   'Inlet_Branch_142_Name',
#   'Inlet_Branch_143_Name',
#   'Inlet_Branch_144_Name',
#   'Inlet_Branch_145_Name',
#   'Inlet_Branch_146_Name',
#   'Inlet_Branch_147_Name',
#   'Inlet_Branch_148_Name',
#   'Inlet_Branch_149_Name',
#   'Inlet_Branch_150_Name',
#   'Inlet_Branch_151_Name',
#   'Inlet_Branch_152_Name',
#   'Inlet_Branch_153_Name',
#   'Inlet_Branch_154_Name',
#   'Inlet_Branch_155_Name',
#   'Inlet_Branch_156_Name',
#   'Inlet_Branch_157_Name',
#   'Inlet_Branch_158_Name',
#   'Inlet_Branch_159_Name',
#   'Inlet_Branch_160_Name',
#   'Inlet_Branch_161_Name',
#   'Inlet_Branch_162_Name',
#   'Inlet_Branch_163_Name',
#   'Inlet_Branch_164_Name',
#   'Inlet_Branch_165_Name',
#   'Inlet_Branch_166_Name',
#   'Inlet_Branch_167_Name',
#   'Inlet_Branch_168_Name',
#   'Inlet_Branch_169_Name',
#   'Inlet_Branch_170_Name',
#   'Inlet_Branch_171_Name',
#   'Inlet_Branch_172_Name',
#   'Inlet_Branch_173_Name',
#   'Inlet_Branch_174_Name',
#   'Inlet_Branch_175_Name',
#   'Inlet_Branch_176_Name',
#   'Inlet_Branch_177_Name',
#   'Inlet_Branch_178_Name',
#   'Inlet_Branch_179_Name',
#   'Inlet_Branch_180_Name',
#   'Inlet_Branch_181_Name',
#   'Inlet_Branch_182_Name',
#   'Inlet_Branch_183_Name',
#   'Inlet_Branch_184_Name',
#   'Inlet_Branch_185_Name',
#   'Inlet_Branch_186_Name',
#   'Inlet_Branch_187_Name',
#   'Inlet_Branch_188_Name',
#   'Inlet_Branch_189_Name',
#   'Inlet_Branch_190_Name',
#   'Inlet_Branch_191_Name',
#   'Inlet_Branch_192_Name',
#   'Inlet_Branch_193_Name',
#   'Inlet_Branch_194_Name',
#   'Inlet_Branch_195_Name',
#   'Inlet_Branch_196_Name',
#   'Inlet_Branch_197_Name',
#   'Inlet_Branch_198_Name',
#   'Inlet_Branch_199_Name',
#   'Inlet_Branch_200_Name',
#   'Inlet_Branch_201_Name',
#   'Inlet_Branch_202_Name',
#   'Inlet_Branch_203_Name',
#   'Inlet_Branch_204_Name',
#   'Inlet_Branch_205_Name',
#   'Inlet_Branch_206_Name',
#   'Inlet_Branch_207_Name',
#   'Inlet_Branch_208_Name',
#   'Inlet_Branch_209_Name',
#   'Inlet_Branch_210_Name',
#   'Inlet_Branch_211_Name',
#   'Inlet_Branch_212_Name',
#   'Inlet_Branch_213_Name',
#   'Inlet_Branch_214_Name',
#   'Inlet_Branch_215_Name',
#   'Inlet_Branch_216_Name',
#   'Inlet_Branch_217_Name',
#   'Inlet_Branch_218_Name',
#   'Inlet_Branch_219_Name',
#   'Inlet_Branch_220_Name',
#   'Inlet_Branch_221_Name',
#   'Inlet_Branch_222_Name',
#   'Inlet_Branch_223_Name',
#   'Inlet_Branch_224_Name',
#   'Inlet_Branch_225_Name',
#   'Inlet_Branch_226_Name',
#   'Inlet_Branch_227_Name',
#   'Inlet_Branch_228_Name',
#   'Inlet_Branch_229_Name',
#   'Inlet_Branch_230_Name',
#   'Inlet_Branch_231_Name',
#   'Inlet_Branch_232_Name',
#   'Inlet_Branch_233_Name',
#   'Inlet_Branch_234_Name',
#   'Inlet_Branch_235_Name',
#   'Inlet_Branch_236_Name',
#   'Inlet_Branch_237_Name',
#   'Inlet_Branch_238_Name',
#   'Inlet_Branch_239_Name',
#   'Inlet_Branch_240_Name',
#   'Inlet_Branch_241_Name',
#   'Inlet_Branch_242_Name',
#   'Inlet_Branch_243_Name',
#   'Inlet_Branch_244_Name',
#   'Inlet_Branch_245_Name',
#   'Inlet_Branch_246_Name',
#   'Inlet_Branch_247_Name',
#   'Inlet_Branch_248_Name',
#   'Inlet_Branch_249_Name',
#   'Inlet_Branch_250_Name',
#   'Inlet_Branch_251_Name',
#   'Inlet_Branch_252_Name',
#   'Inlet_Branch_253_Name',
#   'Inlet_Branch_254_Name',
#   'Inlet_Branch_255_Name',
#   'Inlet_Branch_256_Name',
#   'Inlet_Branch_257_Name',
#   'Inlet_Branch_258_Name',
#   'Inlet_Branch_259_Name',
#   'Inlet_Branch_260_Name',
#   'Inlet_Branch_261_Name',
#   'Inlet_Branch_262_Name',
#   'Inlet_Branch_263_Name',
#   'Inlet_Branch_264_Name',
#   'Inlet_Branch_265_Name',
#   'Inlet_Branch_266_Name',
#   'Inlet_Branch_267_Name',
#   'Inlet_Branch_268_Name',
#   'Inlet_Branch_269_Name',
#   'Inlet_Branch_270_Name',
#   'Inlet_Branch_271_Name',
#   'Inlet_Branch_272_Name',
#   'Inlet_Branch_273_Name',
#   'Inlet_Branch_274_Name',
#   'Inlet_Branch_275_Name',
#   'Inlet_Branch_276_Name',
#   'Inlet_Branch_277_Name',
#   'Inlet_Branch_278_Name',
#   'Inlet_Branch_279_Name',
#   'Inlet_Branch_280_Name',
#   'Inlet_Branch_281_Name',
#   'Inlet_Branch_282_Name',
#   'Inlet_Branch_283_Name',
#   'Inlet_Branch_284_Name',
#   'Inlet_Branch_285_Name',
#   'Inlet_Branch_286_Name',
#   'Inlet_Branch_287_Name',
#   'Inlet_Branch_288_Name',
#   'Inlet_Branch_289_Name',
#   'Inlet_Branch_290_Name',
#   'Inlet_Branch_291_Name',
#   'Inlet_Branch_292_Name',
#   'Inlet_Branch_293_Name',
#   'Inlet_Branch_294_Name',
#   'Inlet_Branch_295_Name',
#   'Inlet_Branch_296_Name',
#   'Inlet_Branch_297_Name',
#   'Inlet_Branch_298_Name',
#   'Inlet_Branch_299_Name',
#   'Inlet_Branch_300_Name',
#   'Inlet_Branch_301_Name',
#   'Inlet_Branch_302_Name',
#   'Inlet_Branch_303_Name',
#   'Inlet_Branch_304_Name',
#   'Inlet_Branch_305_Name',
#   'Inlet_Branch_306_Name',
#   'Inlet_Branch_307_Name',
#   'Inlet_Branch_308_Name',
#   'Inlet_Branch_309_Name',
#   'Inlet_Branch_310_Name',
#   'Inlet_Branch_311_Name',
#   'Inlet_Branch_312_Name',
#   'Inlet_Branch_313_Name',
#   'Inlet_Branch_314_Name',
#   'Inlet_Branch_315_Name',
#   'Inlet_Branch_316_Name',
#   'Inlet_Branch_317_Name',
#   'Inlet_Branch_318_Name',
#   'Inlet_Branch_319_Name',
#   'Inlet_Branch_320_Name',
#   'Inlet_Branch_321_Name',
#   'Inlet_Branch_322_Name',
#   'Inlet_Branch_323_Name',
#   'Inlet_Branch_324_Name',
#   'Inlet_Branch_325_Name',
#   'Inlet_Branch_326_Name',
#   'Inlet_Branch_327_Name',
#   'Inlet_Branch_328_Name',
#   'Inlet_Branch_329_Name',
#   'Inlet_Branch_330_Name',
#   'Inlet_Branch_331_Name',
#   'Inlet_Branch_332_Name',
#   'Inlet_Branch_333_Name',
#   'Inlet_Branch_334_Name',
#   'Inlet_Branch_335_Name',
#   'Inlet_Branch_336_Name',
#   'Inlet_Branch_337_Name',
#   'Inlet_Branch_338_Name',
#   'Inlet_Branch_339_Name',
#   'Inlet_Branch_340_Name',
#   'Inlet_Branch_341_Name',
#   'Inlet_Branch_342_Name',
#   'Inlet_Branch_343_Name',
#   'Inlet_Branch_344_Name',
#   'Inlet_Branch_345_Name',
#   'Inlet_Branch_346_Name',
#   'Inlet_Branch_347_Name',
#   'Inlet_Branch_348_Name',
#   'Inlet_Branch_349_Name',
#   'Inlet_Branch_350_Name',
#   'Inlet_Branch_351_Name',
#   'Inlet_Branch_352_Name',
#   'Inlet_Branch_353_Name',
#   'Inlet_Branch_354_Name',
#   'Inlet_Branch_355_Name',
#   'Inlet_Branch_356_Name',
#   'Inlet_Branch_357_Name',
#   'Inlet_Branch_358_Name',
#   'Inlet_Branch_359_Name',
#   'Inlet_Branch_360_Name',
#   'Inlet_Branch_361_Name',
#   'Inlet_Branch_362_Name',
#   'Inlet_Branch_363_Name',
#   'Inlet_Branch_364_Name',
#   'Inlet_Branch_365_Name',
#   'Inlet_Branch_366_Name',
#   'Inlet_Branch_367_Name',
#   'Inlet_Branch_368_Name',
#   'Inlet_Branch_369_Name',
#   'Inlet_Branch_370_Name',
#   'Inlet_Branch_371_Name',
#   'Inlet_Branch_372_Name',
#   'Inlet_Branch_373_Name',
#   'Inlet_Branch_374_Name',
#   'Inlet_Branch_375_Name',
#   'Inlet_Branch_376_Name',
#   'Inlet_Branch_377_Name',
#   'Inlet_Branch_378_Name',
#   'Inlet_Branch_379_Name',
#   'Inlet_Branch_380_Name',
#   'Inlet_Branch_381_Name',
#   'Inlet_Branch_382_Name',
#   'Inlet_Branch_383_Name',
#   'Inlet_Branch_384_Name',
#   'Inlet_Branch_385_Name',
#   'Inlet_Branch_386_Name',
#   'Inlet_Branch_387_Name',
#   'Inlet_Branch_388_Name',
#   'Inlet_Branch_389_Name',
#   'Inlet_Branch_390_Name',
#   'Inlet_Branch_391_Name',
#   'Inlet_Branch_392_Name',
#   'Inlet_Branch_393_Name',
#   'Inlet_Branch_394_Name',
#   'Inlet_Branch_395_Name',
#   'Inlet_Branch_396_Name',
#   'Inlet_Branch_397_Name',
#   'Inlet_Branch_398_Name',
#   'Inlet_Branch_399_Name',
#   'Inlet_Branch_400_Name',
#   'Inlet_Branch_401_Name',
#   'Inlet_Branch_402_Name',
#   'Inlet_Branch_403_Name',
#   'Inlet_Branch_404_Name',
#   'Inlet_Branch_405_Name',
#   'Inlet_Branch_406_Name',
#   'Inlet_Branch_407_Name',
#   'Inlet_Branch_408_Name',
#   'Inlet_Branch_409_Name',
#   'Inlet_Branch_410_Name',
#   'Inlet_Branch_411_Name',
#   'Inlet_Branch_412_Name',
#   'Inlet_Branch_413_Name',
#   'Inlet_Branch_414_Name',
#   'Inlet_Branch_415_Name',
#   'Inlet_Branch_416_Name',
#   'Inlet_Branch_417_Name',
#   'Inlet_Branch_418_Name',
#   'Inlet_Branch_419_Name',
#   'Inlet_Branch_420_Name',
#   'Inlet_Branch_421_Name',
#   'Inlet_Branch_422_Name',
#   'Inlet_Branch_423_Name',
#   'Inlet_Branch_424_Name',
#   'Inlet_Branch_425_Name',
#   'Inlet_Branch_426_Name',
#   'Inlet_Branch_427_Name',
#   'Inlet_Branch_428_Name',
#   'Inlet_Branch_429_Name',
#   'Inlet_Branch_430_Name',
#   'Inlet_Branch_431_Name',
#   'Inlet_Branch_432_Name',
#   'Inlet_Branch_433_Name',
#   'Inlet_Branch_434_Name',
#   'Inlet_Branch_435_Name',
#   'Inlet_Branch_436_Name',
#   'Inlet_Branch_437_Name',
#   'Inlet_Branch_438_Name',
#   'Inlet_Branch_439_Name',
#   'Inlet_Branch_440_Name',
#   'Inlet_Branch_441_Name',
#   'Inlet_Branch_442_Name',
#   'Inlet_Branch_443_Name',
#   'Inlet_Branch_444_Name',
#   'Inlet_Branch_445_Name',
#   'Inlet_Branch_446_Name',
#   'Inlet_Branch_447_Name',
#   'Inlet_Branch_448_Name',
#   'Inlet_Branch_449_Name',
#   'Inlet_Branch_450_Name',
#   'Inlet_Branch_451_Name',
#   'Inlet_Branch_452_Name',
#   'Inlet_Branch_453_Name',
#   'Inlet_Branch_454_Name',
#   'Inlet_Branch_455_Name',
#   'Inlet_Branch_456_Name',
#   'Inlet_Branch_457_Name',
#   'Inlet_Branch_458_Name',
#   'Inlet_Branch_459_Name',
#   'Inlet_Branch_460_Name',
#   'Inlet_Branch_461_Name',
#   'Inlet_Branch_462_Name',
#   'Inlet_Branch_463_Name',
#   'Inlet_Branch_464_Name',
#   'Inlet_Branch_465_Name',
#   'Inlet_Branch_466_Name',
#   'Inlet_Branch_467_Name',
#   'Inlet_Branch_468_Name',
#   'Inlet_Branch_469_Name',
#   'Inlet_Branch_470_Name',
#   'Inlet_Branch_471_Name',
#   'Inlet_Branch_472_Name',
#   'Inlet_Branch_473_Name',
#   'Inlet_Branch_474_Name',
#   'Inlet_Branch_475_Name',
#   'Inlet_Branch_476_Name',
#   'Inlet_Branch_477_Name',
#   'Inlet_Branch_478_Name',
#   'Inlet_Branch_479_Name',
#   'Inlet_Branch_480_Name',
#   'Inlet_Branch_481_Name',
#   'Inlet_Branch_482_Name',
#   'Inlet_Branch_483_Name',
#   'Inlet_Branch_484_Name',
#   'Inlet_Branch_485_Name',
#   'Inlet_Branch_486_Name',
#   'Inlet_Branch_487_Name',
#   'Inlet_Branch_488_Name',
#   'Inlet_Branch_489_Name',
#   'Inlet_Branch_490_Name',
#   'Inlet_Branch_491_Name',
#   'Inlet_Branch_492_Name',
#   'Inlet_Branch_493_Name',
#   'Inlet_Branch_494_Name',
#   'Inlet_Branch_495_Name',
#   'Inlet_Branch_496_Name',
#   'Inlet_Branch_497_Name',
#   'Inlet_Branch_498_Name',
#   'Inlet_Branch_499_Name',
#   'Inlet_Branch_500_Name'],
#  'CONNECTORLIST': ['key',
#   'Name',
#   'Connector_1_Object_Type',
#   'Connector_1_Name',
#   'Connector_2_Object_Type',
#   'Connector_2_Name'],
#  'NODELIST': ['key',
#   'Name',
#   'Node_1_Name',
#   'Node_2_Name',
#   'Node_3_Name',
#   'Node_4_Name',
#   'Node_5_Name',
#   'Node_6_Name',
#   'Node_7_Name',
#   'Node_8_Name',
#   'Node_9_Name',
#   'Node_10_Name',
#   'Node_11_Name',
#   'Node_12_Name',
#   'Node_13_Name',
#   'Node_14_Name',
#   'Node_15_Name',
#   'Node_16_Name',
#   'Node_17_Name',
#   'Node_18_Name',
#   'Node_19_Name',
#   'Node_20_Name',
#   'Node_21_Name',
#   'Node_22_Name',
#   'Node_23_Name',
#   'Node_24_Name',
#   'Node_25_Name',
#   'Node_26_Name',
#   'Node_27_Name',
#   'Node_28_Name',
#   'Node_29_Name',
#   'Node_30_Name',
#   'Node_31_Name',
#   'Node_32_Name',
#   'Node_33_Name',
#   'Node_34_Name',
#   'Node_35_Name',
#   'Node_36_Name',
#   'Node_37_Name',
#   'Node_38_Name',
#   'Node_39_Name',
#   'Node_40_Name',
#   'Node_41_Name',
#   'Node_42_Name',
#   'Node_43_Name',
#   'Node_44_Name',
#   'Node_45_Name',
#   'Node_46_Name',
#   'Node_47_Name',
#   'Node_48_Name',
#   'Node_49_Name',
#   'Node_50_Name',
#   'Node_51_Name',
#   'Node_52_Name',
#   'Node_53_Name',
#   'Node_54_Name',
#   'Node_55_Name',
#   'Node_56_Name',
#   'Node_57_Name',
#   'Node_58_Name',
#   'Node_59_Name',
#   'Node_60_Name',
#   'Node_61_Name',
#   'Node_62_Name',
#   'Node_63_Name',
#   'Node_64_Name',
#   'Node_65_Name',
#   'Node_66_Name',
#   'Node_67_Name',
#   'Node_68_Name',
#   'Node_69_Name',
#   'Node_70_Name',
#   'Node_71_Name',
#   'Node_72_Name',
#   'Node_73_Name',
#   'Node_74_Name',
#   'Node_75_Name',
#   'Node_76_Name',
#   'Node_77_Name',
#   'Node_78_Name',
#   'Node_79_Name',
#   'Node_80_Name',
#   'Node_81_Name',
#   'Node_82_Name',
#   'Node_83_Name',
#   'Node_84_Name',
#   'Node_85_Name',
#   'Node_86_Name',
#   'Node_87_Name',
#   'Node_88_Name',
#   'Node_89_Name',
#   'Node_90_Name',
#   'Node_91_Name',
#   'Node_92_Name',
#   'Node_93_Name',
#   'Node_94_Name',
#   'Node_95_Name',
#   'Node_96_Name',
#   'Node_97_Name',
#   'Node_98_Name',
#   'Node_99_Name',
#   'Node_100_Name',
#   'Node_101_Name',
#   'Node_102_Name',
#   'Node_103_Name',
#   'Node_104_Name',
#   'Node_105_Name',
#   'Node_106_Name',
#   'Node_107_Name',
#   'Node_108_Name',
#   'Node_109_Name',
#   'Node_110_Name',
#   'Node_111_Name',
#   'Node_112_Name',
#   'Node_113_Name',
#   'Node_114_Name',
#   'Node_115_Name',
#   'Node_116_Name',
#   'Node_117_Name',
#   'Node_118_Name',
#   'Node_119_Name',
#   'Node_120_Name',
#   'Node_121_Name',
#   'Node_122_Name',
#   'Node_123_Name',
#   'Node_124_Name',
#   'Node_125_Name',
#   'Node_126_Name',
#   'Node_127_Name',
#   'Node_128_Name',
#   'Node_129_Name',
#   'Node_130_Name',
#   'Node_131_Name',
#   'Node_132_Name',
#   'Node_133_Name',
#   'Node_134_Name',
#   'Node_135_Name',
#   'Node_136_Name',
#   'Node_137_Name',
#   'Node_138_Name',
#   'Node_139_Name',
#   'Node_140_Name',
#   'Node_141_Name',
#   'Node_142_Name',
#   'Node_143_Name',
#   'Node_144_Name',
#   'Node_145_Name',
#   'Node_146_Name',
#   'Node_147_Name',
#   'Node_148_Name',
#   'Node_149_Name',
#   'Node_150_Name',
#   'Node_151_Name',
#   'Node_152_Name',
#   'Node_153_Name',
#   'Node_154_Name',
#   'Node_155_Name',
#   'Node_156_Name',
#   'Node_157_Name',
#   'Node_158_Name',
#   'Node_159_Name',
#   'Node_160_Name',
#   'Node_161_Name',
#   'Node_162_Name',
#   'Node_163_Name',
#   'Node_164_Name',
#   'Node_165_Name',
#   'Node_166_Name',
#   'Node_167_Name',
#   'Node_168_Name',
#   'Node_169_Name',
#   'Node_170_Name',
#   'Node_171_Name',
#   'Node_172_Name',
#   'Node_173_Name',
#   'Node_174_Name',
#   'Node_175_Name',
#   'Node_176_Name',
#   'Node_177_Name',
#   'Node_178_Name',
#   'Node_179_Name',
#   'Node_180_Name',
#   'Node_181_Name',
#   'Node_182_Name',
#   'Node_183_Name',
#   'Node_184_Name',
#   'Node_185_Name',
#   'Node_186_Name',
#   'Node_187_Name',
#   'Node_188_Name',
#   'Node_189_Name',
#   'Node_190_Name',
#   'Node_191_Name',
#   'Node_192_Name',
#   'Node_193_Name',
#   'Node_194_Name',
#   'Node_195_Name',
#   'Node_196_Name',
#   'Node_197_Name',
#   'Node_198_Name',
#   'Node_199_Name',
#   'Node_200_Name',
#   'Node_201_Name',
#   'Node_202_Name',
#   'Node_203_Name',
#   'Node_204_Name',
#   'Node_205_Name',
#   'Node_206_Name',
#   'Node_207_Name',
#   'Node_208_Name',
#   'Node_209_Name',
#   'Node_210_Name',
#   'Node_211_Name',
#   'Node_212_Name',
#   'Node_213_Name',
#   'Node_214_Name',
#   'Node_215_Name',
#   'Node_216_Name',
#   'Node_217_Name',
#   'Node_218_Name',
#   'Node_219_Name',
#   'Node_220_Name',
#   'Node_221_Name',
#   'Node_222_Name',
#   'Node_223_Name',
#   'Node_224_Name',
#   'Node_225_Name',
#   'Node_226_Name',
#   'Node_227_Name',
#   'Node_228_Name',
#   'Node_229_Name',
#   'Node_230_Name',
#   'Node_231_Name',
#   'Node_232_Name',
#   'Node_233_Name',
#   'Node_234_Name',
#   'Node_235_Name',
#   'Node_236_Name',
#   'Node_237_Name',
#   'Node_238_Name',
#   'Node_239_Name',
#   'Node_240_Name',
#   'Node_241_Name',
#   'Node_242_Name',
#   'Node_243_Name',
#   'Node_244_Name',
#   'Node_245_Name',
#   'Node_246_Name',
#   'Node_247_Name',
#   'Node_248_Name',
#   'Node_249_Name',
#   'Node_250_Name',
#   'Node_251_Name',
#   'Node_252_Name',
#   'Node_253_Name',
#   'Node_254_Name',
#   'Node_255_Name',
#   'Node_256_Name',
#   'Node_257_Name',
#   'Node_258_Name',
#   'Node_259_Name',
#   'Node_260_Name',
#   'Node_261_Name',
#   'Node_262_Name',
#   'Node_263_Name',
#   'Node_264_Name',
#   'Node_265_Name',
#   'Node_266_Name',
#   'Node_267_Name',
#   'Node_268_Name',
#   'Node_269_Name',
#   'Node_270_Name',
#   'Node_271_Name',
#   'Node_272_Name',
#   'Node_273_Name',
#   'Node_274_Name',
#   'Node_275_Name',
#   'Node_276_Name',
#   'Node_277_Name',
#   'Node_278_Name',
#   'Node_279_Name',
#   'Node_280_Name',
#   'Node_281_Name',
#   'Node_282_Name',
#   'Node_283_Name',
#   'Node_284_Name',
#   'Node_285_Name',
#   'Node_286_Name',
#   'Node_287_Name',
#   'Node_288_Name',
#   'Node_289_Name',
#   'Node_290_Name',
#   'Node_291_Name',
#   'Node_292_Name',
#   'Node_293_Name',
#   'Node_294_Name',
#   'Node_295_Name',
#   'Node_296_Name',
#   'Node_297_Name',
#   'Node_298_Name',
#   'Node_299_Name',
#   'Node_300_Name',
#   'Node_301_Name',
#   'Node_302_Name',
#   'Node_303_Name',
#   'Node_304_Name',
#   'Node_305_Name',
#   'Node_306_Name',
#   'Node_307_Name',
#   'Node_308_Name',
#   'Node_309_Name',
#   'Node_310_Name',
#   'Node_311_Name',
#   'Node_312_Name',
#   'Node_313_Name',
#   'Node_314_Name',
#   'Node_315_Name',
#   'Node_316_Name',
#   'Node_317_Name',
#   'Node_318_Name',
#   'Node_319_Name',
#   'Node_320_Name',
#   'Node_321_Name',
#   'Node_322_Name',
#   'Node_323_Name',
#   'Node_324_Name',
#   'Node_325_Name',
#   'Node_326_Name',
#   'Node_327_Name',
#   'Node_328_Name',
#   'Node_329_Name',
#   'Node_330_Name',
#   'Node_331_Name',
#   'Node_332_Name',
#   'Node_333_Name',
#   'Node_334_Name',
#   'Node_335_Name',
#   'Node_336_Name',
#   'Node_337_Name',
#   'Node_338_Name',
#   'Node_339_Name',
#   'Node_340_Name',
#   'Node_341_Name',
#   'Node_342_Name',
#   'Node_343_Name',
#   'Node_344_Name',
#   'Node_345_Name',
#   'Node_346_Name',
#   'Node_347_Name',
#   'Node_348_Name',
#   'Node_349_Name',
#   'Node_350_Name',
#   'Node_351_Name',
#   'Node_352_Name',
#   'Node_353_Name',
#   'Node_354_Name',
#   'Node_355_Name',
#   'Node_356_Name',
#   'Node_357_Name',
#   'Node_358_Name',
#   'Node_359_Name',
#   'Node_360_Name',
#   'Node_361_Name',
#   'Node_362_Name',
#   'Node_363_Name',
#   'Node_364_Name',
#   'Node_365_Name',
#   'Node_366_Name',
#   'Node_367_Name',
#   'Node_368_Name',
#   'Node_369_Name',
#   'Node_370_Name',
#   'Node_371_Name',
#   'Node_372_Name',
#   'Node_373_Name',
#   'Node_374_Name',
#   'Node_375_Name',
#   'Node_376_Name',
#   'Node_377_Name',
#   'Node_378_Name',
#   'Node_379_Name',
#   'Node_380_Name',
#   'Node_381_Name',
#   'Node_382_Name',
#   'Node_383_Name',
#   'Node_384_Name',
#   'Node_385_Name',
#   'Node_386_Name',
#   'Node_387_Name',
#   'Node_388_Name',
#   'Node_389_Name',
#   'Node_390_Name',
#   'Node_391_Name',
#   'Node_392_Name',
#   'Node_393_Name',
#   'Node_394_Name',
#   'Node_395_Name',
#   'Node_396_Name',
#   'Node_397_Name',
#   'Node_398_Name',
#   'Node_399_Name',
#   'Node_400_Name',
#   'Node_401_Name',
#   'Node_402_Name',
#   'Node_403_Name',
#   'Node_404_Name',
#   'Node_405_Name',
#   'Node_406_Name',
#   'Node_407_Name',
#   'Node_408_Name',
#   'Node_409_Name',
#   'Node_410_Name',
#   'Node_411_Name',
#   'Node_412_Name',
#   'Node_413_Name',
#   'Node_414_Name',
#   'Node_415_Name',
#   'Node_416_Name',
#   'Node_417_Name',
#   'Node_418_Name',
#   'Node_419_Name',
#   'Node_420_Name',
#   'Node_421_Name',
#   'Node_422_Name',
#   'Node_423_Name',
#   'Node_424_Name',
#   'Node_425_Name',
#   'Node_426_Name',
#   'Node_427_Name',
#   'Node_428_Name',
#   'Node_429_Name',
#   'Node_430_Name',
#   'Node_431_Name',
#   'Node_432_Name',
#   'Node_433_Name',
#   'Node_434_Name',
#   'Node_435_Name',
#   'Node_436_Name',
#   'Node_437_Name',
#   'Node_438_Name',
#   'Node_439_Name',
#   'Node_440_Name',
#   'Node_441_Name',
#   'Node_442_Name',
#   'Node_443_Name',
#   'Node_444_Name',
#   'Node_445_Name',
#   'Node_446_Name',
#   'Node_447_Name',
#   'Node_448_Name',
#   'Node_449_Name',
#   'Node_450_Name',
#   'Node_451_Name',
#   'Node_452_Name',
#   'Node_453_Name',
#   'Node_454_Name',
#   'Node_455_Name',
#   'Node_456_Name',
#   'Node_457_Name',
#   'Node_458_Name',
#   'Node_459_Name',
#   'Node_460_Name',
#   'Node_461_Name',
#   'Node_462_Name',
#   'Node_463_Name',
#   'Node_464_Name',
#   'Node_465_Name',
#   'Node_466_Name',
#   'Node_467_Name',
#   'Node_468_Name',
#   'Node_469_Name',
#   'Node_470_Name',
#   'Node_471_Name',
#   'Node_472_Name',
#   'Node_473_Name',
#   'Node_474_Name',
#   'Node_475_Name',
#   'Node_476_Name',
#   'Node_477_Name',
#   'Node_478_Name',
#   'Node_479_Name',
#   'Node_480_Name',
#   'Node_481_Name',
#   'Node_482_Name',
#   'Node_483_Name',
#   'Node_484_Name',
#   'Node_485_Name',
#   'Node_486_Name',
#   'Node_487_Name',
#   'Node_488_Name',
#   'Node_489_Name',
#   'Node_490_Name',
#   'Node_491_Name',
#   'Node_492_Name',
#   'Node_493_Name',
#   'Node_494_Name',
#   'Node_495_Name',
#   'Node_496_Name',
#   'Node_497_Name',
#   'Node_498_Name',
#   'Node_499_Name',
#   'Node_500_Name'],
#  'SETPOINTMANAGER:SCHEDULED': ['key',
#   'Name',
#   'Control_Variable',
#   'Schedule_Name',
#   'Setpoint_Node_or_NodeList_Name'],
#  'PLANTLOOP': ['key',
#   'Name',
#   'Fluid_Type',
#   'User_Defined_Fluid_Type',
#   'Plant_Equipment_Operation_Scheme_Name',
#   'Loop_Temperature_Setpoint_Node_Name',
#   'Maximum_Loop_Temperature',
#   'Minimum_Loop_Temperature',
#   'Maximum_Loop_Flow_Rate',
#   'Minimum_Loop_Flow_Rate',
#   'Plant_Loop_Volume',
#   'Plant_Side_Inlet_Node_Name',
#   'Plant_Side_Outlet_Node_Name',
#   'Plant_Side_Branch_List_Name',
#   'Plant_Side_Connector_List_Name',
#   'Demand_Side_Inlet_Node_Name',
#   'Demand_Side_Outlet_Node_Name',
#   'Demand_Side_Branch_List_Name',
#   'Demand_Side_Connector_List_Name',
#   'Load_Distribution_Scheme',
#   'Availability_Manager_List_Name',
#   'Plant_Loop_Demand_Calculation_Scheme',
#   'Common_Pipe_Simulation',
#   'Pressure_Simulation_Type',
#   'Loop_Circulation_Time'],
#  'PLANTEQUIPMENTLIST': ['key',
#   'Name',
#   'Equipment_1_Object_Type',
#   'Equipment_1_Name',
#   'Equipment_2_Object_Type',
#   'Equipment_2_Name',
#   'Equipment_3_Object_Type',
#   'Equipment_3_Name',
#   'Equipment_4_Object_Type',
#   'Equipment_4_Name',
#   'Equipment_5_Object_Type',
#   'Equipment_5_Name',
#   'Equipment_6_Object_Type',
#   'Equipment_6_Name',
#   'Equipment_7_Object_Type',
#   'Equipment_7_Name',
#   'Equipment_8_Object_Type',
#   'Equipment_8_Name',
#   'Equipment_9_Object_Type',
#   'Equipment_9_Name',
#   'Equipment_10_Object_Type',
#   'Equipment_10_Name'],
#  'PLANTEQUIPMENTOPERATION:HEATINGLOAD': ['key',
#   'Name',
#   'Load_Range_1_Lower_Limit',
#   'Load_Range_1_Upper_Limit',
#   'Range_1_Equipment_List_Name',
#   'Load_Range_2_Lower_Limit',
#   'Load_Range_2_Upper_Limit',
#   'Range_2_Equipment_List_Name',
#   'Load_Range_3_Lower_Limit',
#   'Load_Range_3_Upper_Limit',
#   'Range_3_Equipment_List_Name',
#   'Load_Range_4_Lower_Limit',
#   'Load_Range_4_Upper_Limit',
#   'Range_4_Equipment_List_Name',
#   'Load_Range_5_Lower_Limit',
#   'Load_Range_5_Upper_Limit',
#   'Range_5_Equipment_List_Name',
#   'Load_Range_6_Lower_Limit',
#   'Load_Range_6_Upper_Limit',
#   'Range_6_Equipment_List_Name',
#   'Load_Range_7_Lower_Limit',
#   'Load_Range_7_Upper_Limit',
#   'Range_7_Equipment_List_Name',
#   'Load_Range_8_Lower_Limit',
#   'Load_Range_8_Upper_Limit',
#   'Range_8_Equipment_List_Name',
#   'Load_Range_9_Lower_Limit',
#   'Load_Range_9_Upper_Limit',
#   'Range_9_Equipment_List_Name',
#   'Load_Range_10_Lower_Limit',
#   'Load_Range_10_Upper_Limit',
#   'Range_10_Equipment_List_Name'],
#  'PLANTEQUIPMENTOPERATIONSCHEMES': ['key',
#   'Name',
#   'Control_Scheme_1_Object_Type',
#   'Control_Scheme_1_Name',
#   'Control_Scheme_1_Schedule_Name',
#   'Control_Scheme_2_Object_Type',
#   'Control_Scheme_2_Name',
#   'Control_Scheme_2_Schedule_Name',
#   'Control_Scheme_3_Object_Type',
#   'Control_Scheme_3_Name',
#   'Control_Scheme_3_Schedule_Name',
#   'Control_Scheme_4_Object_Type',
#   'Control_Scheme_4_Name',
#   'Control_Scheme_4_Schedule_Name',
#   'Control_Scheme_5_Object_Type',
#   'Control_Scheme_5_Name',
#   'Control_Scheme_5_Schedule_Name',
#   'Control_Scheme_6_Object_Type',
#   'Control_Scheme_6_Name',
#   'Control_Scheme_6_Schedule_Name',
#   'Control_Scheme_7_Object_Type',
#   'Control_Scheme_7_Name',
#   'Control_Scheme_7_Schedule_Name',
#   'Control_Scheme_8_Object_Type',
#   'Control_Scheme_8_Name',
#   'Control_Scheme_8_Schedule_Name'],
#  'WATERUSE:EQUIPMENT': ['key',
#   'Name',
#   'EndUse_Subcategory',
#   'Peak_Flow_Rate',
#   'Flow_Rate_Fraction_Schedule_Name',
#   'Target_Temperature_Schedule_Name',
#   'Hot_Water_Supply_Temperature_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name',
#   'Zone_Name',
#   'Sensible_Fraction_Schedule_Name',
#   'Latent_Fraction_Schedule_Name'],
#  'WATERUSE:CONNECTIONS': ['key',
#   'Name',
#   'Inlet_Node_Name',
#   'Outlet_Node_Name',
#   'Supply_Water_Storage_Tank_Name',
#   'Reclamation_Water_Storage_Tank_Name',
#   'Hot_Water_Supply_Temperature_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name',
#   'Drain_Water_Heat_Exchanger_Type',
#   'Drain_Water_Heat_Exchanger_Destination',
#   'Drain_Water_Heat_Exchanger_UFactor_Times_Area',
#   'Water_Use_Equipment_1_Name',
#   'Water_Use_Equipment_2_Name',
#   'Water_Use_Equipment_3_Name',
#   'Water_Use_Equipment_4_Name',
#   'Water_Use_Equipment_5_Name',
#   'Water_Use_Equipment_6_Name',
#   'Water_Use_Equipment_7_Name',
#   'Water_Use_Equipment_8_Name',
#   'Water_Use_Equipment_9_Name',
#   'Water_Use_Equipment_10_Name'],
#  'CURVE:QUADRATIC': ['key',
#   'Name',
#   'Coefficient1_Constant',
#   'Coefficient2_x',
#   'Coefficient3_x2',
#   'Minimum_Value_of_x',
#   'Maximum_Value_of_x',
#   'Minimum_Curve_Output',
#   'Maximum_Curve_Output',
#   'Input_Unit_Type_for_X',
#   'Output_Unit_Type'],
#  'CURVE:CUBIC': ['key',
#   'Name',
#   'Coefficient1_Constant',
#   'Coefficient2_x',
#   'Coefficient3_x2',
#   'Coefficient4_x3',
#   'Minimum_Value_of_x',
#   'Maximum_Value_of_x',
#   'Minimum_Curve_Output',
#   'Maximum_Curve_Output',
#   'Input_Unit_Type_for_X',
#   'Output_Unit_Type'],
#  'CURVE:BIQUADRATIC': ['key',
#   'Name',
#   'Coefficient1_Constant',
#   'Coefficient2_x',
#   'Coefficient3_x2',
#   'Coefficient4_y',
#   'Coefficient5_y2',
#   'Coefficient6_xy',
#   'Minimum_Value_of_x',
#   'Maximum_Value_of_x',
#   'Minimum_Value_of_y',
#   'Maximum_Value_of_y',
#   'Minimum_Curve_Output',
#   'Maximum_Curve_Output',
#   'Input_Unit_Type_for_X',
#   'Input_Unit_Type_for_Y',
#   'Output_Unit_Type']}

# %% [markdown]
# Now we narrow down the dictionary to those fieldnames containing "Schedule". We only keep the object type and its fieldnames that have "Schedule".

# %%
schedule_key='Schedule'
obj_fieldnames_dict_with_schedule = {
    k: [value for value in v if schedule_key in value]
    for k, v in obj_fieldnames_dict.items() 
    if any(schedule_key in value for value in v)
}
obj_fieldnames_dict_with_schedule
# Out:
# {'Sizing:ZONE': ['Zone_Humidistat_Dehumidification_Set_Point_Schedule_Name',
#   'Zone_Humidistat_Humidification_Set_Point_Schedule_Name'],
#  'FAN:SYSTEMMODEL': ['Availability_Schedule_Name'],
#  'PUMP:CONSTANTSPEED': ['Pump_Flow_Rate_Schedule_Name'],
#  'WATERHEATER:STRATIFIED': ['Heater_1_Setpoint_Temperature_Schedule_Name',
#   'Heater_2_Setpoint_Temperature_Schedule_Name',
#   'Ambient_Temperature_Schedule_Name',
#   'Use_Flow_Rate_Fraction_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name',
#   'Indirect_Alternate_Setpoint_Temperature_Schedule_Name'],
#  'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER': ['Availability_Schedule_Name',
#   'Compressor_Setpoint_Temperature_Schedule_Name',
#   'Inlet_Air_Temperature_Schedule_Name',
#   'Inlet_Air_Humidity_Schedule_Name',
#   'Compressor_Ambient_Temperature_Schedule_Name',
#   'Inlet_Air_Mixer_Schedule_Name'],
#  'SETPOINTMANAGER:SCHEDULED': ['Schedule_Name'],
#  'PLANTEQUIPMENTOPERATIONSCHEMES': ['Control_Scheme_1_Schedule_Name',
#   'Control_Scheme_2_Schedule_Name',
#   'Control_Scheme_3_Schedule_Name',
#   'Control_Scheme_4_Schedule_Name',
#   'Control_Scheme_5_Schedule_Name',
#   'Control_Scheme_6_Schedule_Name',
#   'Control_Scheme_7_Schedule_Name',
#   'Control_Scheme_8_Schedule_Name'],
#  'WATERUSE:EQUIPMENT': ['Flow_Rate_Fraction_Schedule_Name',
#   'Target_Temperature_Schedule_Name',
#   'Hot_Water_Supply_Temperature_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name',
#   'Sensible_Fraction_Schedule_Name',
#   'Latent_Fraction_Schedule_Name'],
#  'WATERUSE:CONNECTIONS': ['Hot_Water_Supply_Temperature_Schedule_Name',
#   'Cold_Water_Supply_Temperature_Schedule_Name']}

# %% [markdown]
# Dissecting the dictionary, we have dictionary keys indicating object types that use schedule as input.

# %%
obj_type_with_schedule=list(obj_fieldnames_dict_with_schedule.keys())
obj_type_with_schedule
# Out:
# ['Sizing:ZONE',
#  'FAN:SYSTEMMODEL',
#  'PUMP:CONSTANTSPEED',
#  'WATERHEATER:STRATIFIED',
#  'WATERHEATER:HEATPUMP:WRAPPEDCONDENSER',
#  'SETPOINTMANAGER:SCHEDULED',
#  'PLANTEQUIPMENTOPERATIONSCHEMES',
#  'WATERUSE:EQUIPMENT',
#  'WATERUSE:CONNECTIONS']

# %% [markdown]
# Now we can pull out all schedules used by the new WH system.

# %%
used_schedules = []
for obj_type in obj_type_with_schedule:
    
    #Pull out the list of fieldnames with "Schedule"
    schedule_field = obj_fieldnames_dict_with_schedule[obj_type]
    
    #Check each field and pull out the name of the schedule used
    for field in schedule_field:
        schedule = getattr(targetidf.idfobjects[obj_type][0], field, None)
        if schedule != None:
            used_schedules.append(schedule)

#Remove empty schedules
used_schedules = [sch for sch in used_schedules if sch != '']

# %%
used_schedules
# Out:
# ['always_avail',
#  'SWHSys1 Water Heater Setpoint Temperature Schedule Name',
#  'SWHSys1 Water Heater Setpoint Temperature Schedule Name',
#  'SWHSys1 Water Heater Ambient Temperature Schedule Name',
#  'always_avail',
#  'PlantHPWHTempSch',
#  'DHWSupplySetpoint',
#  'always_avail',
#  'ClothesWasher',
#  'CWWaterTempSchedule']

# %% [markdown]
# Now we go back to the existing schedules. There are a few different object types for schedules.

# %%
schedule_obj_type = [sch for sch in unique_target_list if 'SCHEDULE' in sch]
schedule_obj_type
# Out:
# ['SCHEDULETYPELIMITS',
#  'SCHEDULE:DAY:HOURLY',
#  'SCHEDULE:WEEK:COMPACT',
#  'SCHEDULE:YEAR',
#  'SCHEDULE:COMPACT',
#  'SCHEDULE:CONSTANT',
#  'AVAILABILITYMANAGER:SCHEDULED',
#  'SETPOINTMANAGER:SCHEDULED']

# %% [markdown]
# We review each schedule type and pull out the name of all existing schedules.

# %%
existing_schedules=[]
for sch_type in schedule_obj_type:
    for i in range(len(targetidf.idfobjects[sch_type])):
        sch = targetidf.idfobjects[sch_type][i].Name
        existing_schedules.append(sch)

existing_schedules
# Out:
# ['any number',
#  'On/Off',
#  'control_type',
#  'fraction',
#  'Temperature',
#  'OccupancyDay',
#  'LightingDay',
#  'LightingDay_EELighting_OccSensors',
#  'LightingDay_EELighting_Garage_OccSensors',
#  'ExteriorLightingDay',
#  'LightingDay_EELighting',
#  'RefrigeratorDay',
#  'MiscPlugLoadDay',
#  'CookingRangeDay',
#  'DishwasherWeekday',
#  'DishwasherWeekend',
#  'DishwasherVacation',
#  'ClothesWasherWeekday',
#  'ClothesWasherWeekend',
#  'ClothesWasherVacation',
#  'dhw_profile_day',
#  'ClothesDryerWeekday',
#  'ClothesDryerWeekend',
#  'ClothesDryerVacation',
#  'SinksWeekday',
#  'SinksWeekend',
#  'SinksVacation',
#  'ShowersWeekday',
#  'ShowersWeekend',
#  'ShowersVacation',
#  'BathsWeekday',
#  'BathsWeekend',
#  'BathsVacation',
#  'DHWDistDay',
#  'WinterLoadDay',
#  'SummerLoadDay',
#  'RefrigeratorWeek',
#  'MiscPlugLoadWeek',
#  'CookingRangeWeek',
#  'DishwasherWeek',
#  'ClothesWasherWeek',
#  'dhw_profile_week',
#  'ClothesDryerWeek',
#  'SinksWeek',
#  'ShowersWeek',
#  'BathsWeek',
#  'DHWDistWeek',
#  'OccupancyWeek',
#  'LightingProfileWeek',
#  'LightingProfileWeek_EELighting',
#  'LightingProfileWeek_EELighting_interior_controls',
#  'LightingProfileWeek_EELighting_garage_controls',
#  'ExteriorLightingProfileWeek',
#  'Occupancy',
#  'InteriorLighting',
#  'InteriorLightingHE',
#  'InteriorLightingHE_OS',
#  'InteriorLightingHE_VS',
#  'ExteriorLighting',
#  'Refrigerator',
#  'MiscPlugLoad',
#  'CookingRange',
#  'dhw_sch',
#  'Dishwasher',
#  'ClothesWasher',
#  'ClothesDryer',
#  'Sinks',
#  'Showers',
#  'Baths',
#  'DHWDist',
#  'BA_shower_sch',
#  'BA_bath_sch',
#  'BA_sink_sch',
#  'activity_sch',
#  'inf_sch',
#  'zone_control_type',
#  'shading_2012iecc',
#  'shading_2009iecc',
#  'dhw_setpt',
#  'dhw_setpt_hpwh',
#  'Supply-Air-Temp-Sch',
#  'always_avail',
#  'always_off',
#  'heating_sch_HRef',
#  'cooling_sch_HRef',
#  'heating_sch',
#  'cooling_sch',
#  'fan_cycle',
#  'DWWaterTempSchedule',
#  'CWWaterTempSchedule',
#  'SinkSensSchedule',
#  'SinkLatSchedule',
#  'ShowerSensSchedule',
#  'ShowerLatSchedule',
#  'BathSensSchedule',
#  'BathLatSchedule',
#  'SSBWaterTempSchedule',
#  'WaterHeaterSP1Schedule',
#  'WaterHeaterSP2Schedule',
#  'DHWSupplySetpoint',
#  'boiler_setpt',
#  'Compressor Setpoint',
#  'DOAShightemp',
#  'DOASlowtemp',
#  'System availability',
#  'DHW Loop Setpoint Manager_unit1_FrontRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit2_FrontRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit3_FrontRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit1_BackRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit2_BackRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit3_BackRow_BottomFloor',
#  'DHW Loop Setpoint Manager_unit1_FrontRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit2_FrontRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit3_FrontRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit1_BackRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit2_BackRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit3_BackRow_MiddleFloor',
#  'DHW Loop Setpoint Manager_unit1_FrontRow_TopFloor',
#  'DHW Loop Setpoint Manager_unit2_FrontRow_TopFloor',
#  'DHW Loop Setpoint Manager_unit3_FrontRow_TopFloor',
#  'DHW Loop Setpoint Manager_unit1_BackRow_TopFloor',
#  'DHW Loop Setpoint Manager_unit2_BackRow_TopFloor',
#  'DHW Loop Setpoint Manager_unit3_BackRow_TopFloor']

# %% [markdown]
# Check if any used schedules are not prepared in the Schedule objects.

# %%
new_sch_needed = list(set(used_schedules) - set(existing_schedules))
new_sch_needed
# Out:
# ['SWHSys1 Water Heater Setpoint Temperature Schedule Name',
#  'SWHSys1 Water Heater Ambient Temperature Schedule Name',
#  'PlantHPWHTempSch']

# %%
matching_objects = []

if len(new_sch_needed) > 0:    
    for sch in new_sch_needed:
    
    # Iterate through all objects in the source file
        for obj_type in sourceidf.idfobjects:  # Loop through all object types
            for obj in sourceidf.idfobjects[obj_type]:  # Loop through all objects of that type
                
                # Check if the schedule name appears in any field of the object
                if sch in obj.fieldvalues:
                    if "SCHEDULE" in obj_type: #Make sure only the Schedule object is included, not the object that uses the schedule
                        matching_objects.append(obj)
    
    #Copy the new schedules to the target file
    for new_obj in matching_objects:
        targetidf.copyidfobject(new_obj)

# %%
matching_objects
# Out:
# [
#  Schedule:Compact,
#      SWHSys1 Water Heater Setpoint Temperature Schedule Name,    !- Name
#      Temperature,              !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      60.0;                     !- Field 4,
#
#  Schedule:Compact,
#      SWHSys1 Water Heater Ambient Temperature Schedule Name,    !- Name
#      Temperature,              !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      22.0;                     !- Field 4,
#
#  Schedule:Compact,
#      PlantHPWHTempSch,         !- Name
#      Any Number,               !- Schedule Type Limits Name
#      Through: 12/31,           !- Field 1
#      For: AllDays,             !- Field 2
#      Until: 24:00,             !- Field 3
#      48.89;                    !- Field 4]

# %% [markdown]
# # Save as

# %%
targetidf.saveas('US+MF+CZ2AWH+gasfurnace+slab+IECC_2006_HPWH.idf')
